# %%
#🔵
main_path = '/Users/stanislavkrupnov/Jup.Notebook'

# %%
#🟠
main_path = '/content/drive/Othercomputers/Mac/Jup.Notebook'

# %% [markdown]
# # Цель ноутбука

# %% [markdown]
# Выбираю лучшую бейзлайн-модель для второго этапа рек.системы - ранжирования
# первичных кандидатов внутри каждой сессии на основе признаков и таргетов.
# Выбор будет происходить между **XGBoost Ranker, CatBoost Ranker, LGBM Ranker**

# %% [markdown]
# # Функции

# %%
def metric_eval(predictions: pd.DataFrame, valid: pd.DataFrame,
                id2type: dict) -> tuple:
    """
    Вычисляет метрики для оценки качества модели.

    Parameters:
    - predictions (pd.DataFrame): DataFrame с предсказаниями модели.
    - valid (pd.DataFrame): DataFrame с данными для валидации.
    - id2type (dict): Словарь для преобразования индексов типов в соответствующие строки.

    Returns:
    - tuple: Кортеж, содержащий локальную метрику и реколл для каждого типа.
    """
    # Преобразование индексов типов в соответствующие строки
    valid.type = valid.type.map(lambda idx: id2type[idx])

    # Создание списка с метками для каждой сессии и типа
    ground_truth = valid.groupby(['session', 'type'])['aid'].apply(list)
    ground_truth = ground_truth.reset_index().rename(columns={'aid': 'labels'})

    # Обрезка меток для типа 'clicks' до одной метки
    ground_truth.loc[ground_truth.type == 'clicks',
                     'labels'] = ground_truth.loc[ground_truth.type ==
                                                  'clicks', 'labels'].str[:1]

    # Объединение предсказаний с истинными метками
    submission_with_gt = predictions.merge(
        ground_truth[['session', 'type', 'labels']],
        how='left',
        on=['session', 'type'])

    # Отбрасывание сессий без истинных меток
    submission_with_gt = submission_with_gt[~submission_with_gt.labels_y.isna(
    )]

    # Вычисление количества совпадений между предсказанными и истинными метками
    submission_with_gt['hits'] = submission_with_gt.apply(
        lambda df: len(set(df.labels_x).intersection(set(df.labels_y))),
        axis=1)

    # Вычисление количества истинных меток для каждого типа
    submission_with_gt['gt_count'] = submission_with_gt.labels_y.str.len(
    ).clip(0, 20)

    # Вычисление реколла для каждого типа
    recall_per_type = submission_with_gt.groupby([
        'type'
    ])['hits'].sum() / submission_with_gt.groupby(['type'])['gt_count'].sum()

    # Вычисление локальной метрики на основе реколла для каждого типа
    local_validation_score = (recall_per_type * pd.Series({
        'clicks': 0.10,
        'carts': 0.30,
        'orders': 0.60
    })).sum()

    return local_validation_score, recall_per_type

# %%
def read_parquets(path):
    """
    Чтение данных из файлов Parquet и их объединение в единый DataFrame.

    Parameters:
    - path (str): Путь к файлам Parquet.

    Returns:
    - tr_candidates (pd.DataFrame): Объединенный DataFrame.
    """
    # Список файлов Parquet
    file_list = glob.glob(path)

    # Создание пустого DataFrame для сбора данных
    tr_candidates = pd.DataFrame()

    # Цикл для чтения и объединения файлов
    for file in tqdm(file_list):
        # Чтение файла Parquet во временный DataFrame
        df_ = pd.read_parquet(file)

        # Объединение временного DataFrame с основным датасетом
        tr_candidates = pd.concat([tr_candidates, df_], ignore_index=True)

    return tr_candidates

# %% [markdown]
# # Import

# %%
import os
import sys
from tqdm import tqdm
import glob
import pyarrow.parquet as pq
import pickle
import pandas as pd
import gc
import numpy as np
import itertools
from datetime import datetime as dt
import polars as pl
import shutil
import xgboost as xgb
from sklearn.model_selection import GroupKFold
from imblearn.under_sampling import RandomUnderSampler
import joblib

# %%
import lightgbm as lgb
from lightgbm.sklearn import LGBMRanker

# %%
import gdown
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # XGBoost Baseline

# %% [markdown]
# ## Тренировка

# %%
ver_folder = 'xgb_base'
random_state = 42
# slice_value = 1
downsamp_k = 16

# %%
# Перебор типов 'clicks', 'carts', 'orders'
for typee in tqdm(['clicks', 'carts', 'orders'], desc='type'):

    # Путь к файлам Parquet для текущего типа
    path = f'{main_path}/tr/ver_6/tr_candidates_{typee}/*'

    # Чтение данных из файлов Parquet
    tr_candidates = read_parquets(path)
    print('Чтение данных завершено')

    # Преобразование типов данных
    tr_candidates.session = tr_candidates.session.astype(np.int32)
    tr_candidates.aid = tr_candidates.aid.astype(np.int32)

    # Расчет соотношения классов
    class_ratio = tr_candidates['target'].value_counts(
    )[1] / tr_candidates['target'].value_counts()[0]

    # Указание желаемого соотношения классов
    under_sampler = RandomUnderSampler(sampling_strategy=class_ratio *
                                       downsamp_k)

    # Undersampling классов для лучшего баланса
    FEATURES = tr_candidates.columns[:-1]
    X = tr_candidates.loc[:, FEATURES]
    y = tr_candidates.loc[:, 'target']
    X_train, y_train = under_sampler.fit_resample(X, y)
    tr_candidates = pd.merge(X_train,
                             y_train,
                             left_index=True,
                             right_index=True)
    del X, y
    print('Undersampling классов завершено')

    # Обучение модели XGBoost
    folder_path = f'model/baseline/{ver_folder}'
    os.makedirs(folder_path, exist_ok=True)

    # Сортировка и сброс индексов
    tr_candidates = tr_candidates.sort_values('session')
    tr_candidates = tr_candidates.reset_index(drop=True)

    FEATURES = tr_candidates.columns[:-1]

    X_train = tr_candidates[FEATURES]
    y_train = tr_candidates['target']

    # Группировка по сессиям и подсчет числа действий
    group_sizes_tr = X_train.groupby('session')[['aid']].count()

    # Удаление ненужных столбцов
    X_train = X_train.iloc[:, 2:]

    # Подготовка данных для XGBoost
    dtrain = xgb.DMatrix(X_train, y_train, group=group_sizes_tr.aid.tolist())

    # Параметры XGBoost
    xgb_params = {'objective': 'rank:pairwise', 'tree_method': 'gpu_hist'}

    # Обучение модели
    model = xgb.train(xgb_params, dtrain=dtrain, verbose_eval=100)

    # Сохранение модели
    model.save_model(f'model/baseline/{ver_folder}/XGB_base_{typee}.xgb')
    print('training_done')

    # Сохранение модели на диск
    # folder_path = f'{main_path}/models/{ver_folder}/'
    # os.makedirs(folder_path, exist_ok=True)

    # file_list = glob.glob(f'/content/model/*{typee}.xgb')
    # [shutil.copy(file, f'{main_path}/models/{ver_folder}/') for file in file_list]
# Out:
# type:   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:08,  2.24s/it]
#  40%|████      | 2/5 [00:05<00:09,  3.07s/it]
#  60%|██████    | 3/5 [00:10<00:07,  3.68s/it]
#  80%|████████  | 4/5 [00:15<00:04,  4.24s/it]
# 100%|██████████| 5/5 [00:21<00:00,  4.25s/it]
# reading_done
# sampling_done
# type:  33%|███▎      | 1/3 [01:16<02:33, 76.56s/it]
# training_done
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:06<00:25,  6.49s/it]
#  40%|████      | 2/5 [00:14<00:22,  7.46s/it]
#  60%|██████    | 3/5 [00:22<00:15,  7.63s/it]
#  80%|████████  | 4/5 [00:32<00:08,  8.72s/it]
# 100%|██████████| 5/5 [00:44<00:00,  8.93s/it]
# reading_done
# sampling_done
# type:  67%|██████▋   | 2/3 [02:59<01:32, 92.04s/it]
# training_done
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:08<00:34,  8.65s/it]
#  40%|████      | 2/5 [00:16<00:24,  8.28s/it]
#  60%|██████    | 3/5 [00:26<00:17,  8.88s/it]
#  80%|████████  | 4/5 [00:35<00:08,  8.88s/it]
# 100%|██████████| 5/5 [00:46<00:00,  9.20s/it]
# reading_done
# sampling_done
# type: 100%|██████████| 3/3 [04:43<00:00, 94.57s/it]
# training_done

# %% [markdown]
# ## Предсказание + оценка

# %%
lv_predictions_full = pd.DataFrame()

# Перебор типов 'clicks', 'carts', 'orders'
for typee in tqdm(['clicks', 'carts', 'orders'], desc='type'):

    # Проверка наличия директории с кандидатами
    if not os.path.exists(f'/content/test_candidates_{typee}'):
        # Импорт кандидатов выбранного типа
        shutil.copytree(f'{main_path}/lv/ver_6/test_candidates_{typee}/',
                        f'/content/test_candidates_{typee}/')

    # Путь к файлам Parquet для текущего типа
    path = f'test_candidates_{typee}/*'

    # Чтение данных из файлов Parquet
    test_candidates = read_parquets(path)
    test_candidates = test_candidates.sort_values('session')
    test_candidates = test_candidates.reset_index(drop=True)

    FEATURES = test_candidates.columns[2:]

    # Подготовка массива для предсказаний
    preds = np.zeros(len(test_candidates))

    # Загрузка обученной модели
    model = xgb.Booster()
    model.load_model(f'model/baseline/{ver_folder}/XGB_base_{typee}.xgb')
    model.set_param({'predictor': 'gpu_predictor'})

    # Подготовка данных для XGBoost
    dtest = xgb.DMatrix(data=test_candidates[FEATURES])

    # Предсказание
    preds = model.predict(dtest)

    # Формирование DataFrame с предсказаниями
    lv_predictions = test_candidates[['session', 'aid']].copy()
    lv_predictions['pred'] = preds
    lv_predictions = lv_predictions.sort_values(
        ['session', 'pred'], ascending=[True, False]).reset_index(drop=True)
    lv_predictions['n'] = lv_predictions.groupby(
        'session').aid.cumcount().astype('int8')
    lv_predictions = lv_predictions.loc[lv_predictions.n < 20]
    lv_predictions = lv_predictions.groupby('session').aid.apply(list)
    lv_predictions = lv_predictions.to_frame().reset_index()
    lv_predictions.rename(columns={'aid': 'labels'}, inplace=True)
    lv_predictions['type'] = typee

    # Объединение временного DataFrame с основным датасетом
    lv_predictions_full = pd.concat([lv_predictions_full, lv_predictions],
                                    ignore_index=True)
    del lv_predictions, preds, dtest, test_candidates

# lv_predictions.to_parquet(f'lv_predictions_{typee}.parquet')
# shutil.copy2(f'lv_predictions_{typee}.parquet', f'{main_path}/lv/{ver_folder}/lv_predictions_{typee}.parquet' )
# Out:
# type:   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:03,  1.31it/s]
#  40%|████      | 2/5 [00:02<00:03,  1.11s/it]
#  60%|██████    | 3/5 [00:03<00:02,  1.34s/it]
#  80%|████████  | 4/5 [00:05<00:01,  1.54s/it]
# 100%|██████████| 5/5 [00:07<00:00,  1.53s/it]
# type:  33%|███▎      | 1/3 [00:50<01:41, 50.98s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:03,  1.26it/s]
#  40%|████      | 2/5 [00:02<00:03,  1.08s/it]
#  60%|██████    | 3/5 [00:03<00:02,  1.32s/it]
#  80%|████████  | 4/5 [00:05<00:01,  1.52s/it]
# 100%|██████████| 5/5 [00:07<00:00,  1.53s/it]
# type:  67%|██████▋   | 2/3 [01:41<00:50, 50.76s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:03,  1.32it/s]
#  40%|████      | 2/5 [00:02<00:03,  1.06s/it]
#  60%|██████    | 3/5 [00:03<00:02,  1.30s/it]
#  80%|████████  | 4/5 [00:05<00:01,  1.57s/it]
# 100%|██████████| 5/5 [00:07<00:00,  1.55s/it]
# type: 100%|██████████| 3/3 [02:38<00:00, 52.97s/it]

# %%
id2type_name = 'id2type.pkl'
# version = 'ver_6.1'

# %%
valid = pd.read_parquet(f'{main_path}/s/test_labels_loc.parquet')

with open(f'{main_path}/pkl/{id2type_name}', 'rb') as file:
    id2type = pickle.load(file)

print('Model score :', metric_eval(lv_predictions_full, valid, id2type))
# Out:
# Model score : (0.5220552152693079, type
# carts     0.365164
# clicks    0.386253
# orders    0.623134
# dtype: float64)

# %%
best_score_base = {'xgb': 0.5220552152693079}

# %% [markdown]
# # LGBM Baseline

# %% [markdown]
# ## Тренировка

# %%
ver_folder = 'lgbm_base'
random_state = 42
# slice_value = 1
downsamp_k = 16

# %%
for typee in tqdm(['clicks', 'carts', 'orders'], desc='type'):

    # Загрузка предварительно сэмплированных кандидатов
    tr_candidates = pd.read_parquet(
        f'{main_path}/tr/ver_6/downsampled/tr_candidates_{typee}.parquet')
    print('reading_done')

    # В данном участке кода отключены downsample и перевод в int32,
    # поскольку они не используются
    # tr_candidates.session = tr_candidates.session.astype(np.int32)
    # tr_candidates.aid = tr_candidates.aid.astype(np.int32)

    # Downsampling трен.датасета
    # class_ratio = tr_candidates['target'].value_counts()[1] / \
    #               tr_candidates['target'].value_counts()[0]
    # under_sampler = RandomUnderSampler(sampling_strategy=class_ratio * downsamp_k)
    # FEATURES = tr_candidates.columns[:-1]
    # X = tr_candidates.loc[:, FEATURES]
    # y = tr_candidates.loc[:, 'target']
    # X_train, y_train = under_sampler.fit_resample(X, y)
    # tr_candidates = pd.merge(X_train, y_train, left_index=True, right_index=True)
    # del X, y
    print('sampling_done')

    # Обучение модели LGBMRanker
    folder_path = f'model/baseline/{ver_folder}'
    os.makedirs(folder_path, exist_ok=True)

    tr_candidates = tr_candidates.sort_values('session')
    tr_candidates = tr_candidates.reset_index(drop=True)

    FEATURES = tr_candidates.columns[:-1]

    # Создание объекта LGBMRanker
    ranker = LGBMRanker(objective="lambdarank")

    X_train = tr_candidates[FEATURES]
    y_train = tr_candidates['target']

    group_id_tr = X_train.groupby('session').size().tolist()
    X_train = X_train.iloc[:, 2:]  # Убираю ['session','aid'] для обучения

    # Обучение ранкера
    ranker = ranker.fit(X_train, tr_candidates['target'], group=group_id_tr)

    # Сохранение модели
    folder_path = f'model/baseline/{ver_folder}'
    os.makedirs(folder_path, exist_ok=True)
    joblib.dump(ranker, f'model/baseline/{ver_folder}/LGB_base_{typee}.joblib')
    print('training_done')

# Сохранение модели на диск
# folder_path = f'{main_path}/models/{ver_folder}/'
# os.makedirs(folder_path, exist_ok=True)

# file_list = glob.glob(f'/content/model/*{typee}.xgb')
# [shutil.copy(file, f'{main_path}/models/{ver_folder}/') for file in file_list]

# %% [markdown]
# ## Предсказание + оценка

# %%
lv_predictions_full = pd.DataFrame()

for typee in tqdm(['clicks', 'carts', 'orders'], desc='type'):

    if os.path.exists(f'/content/test_candidates_{typee}') == False:
        # импорт кандидатов выбранного типа
        shutil.copytree(f'{main_path}/lv/ver_6/test_candidates_{typee}/',
                        f'/content/test_candidates_{typee}/')

    path = f'test_candidates_{typee}/*'
    test_candidates = read_parquets(path)
    test_candidates = test_candidates.sort_values('session')
    test_candidates = test_candidates.reset_index(drop=True)

    # Создание предсказаний
    FEATURES = test_candidates.columns[2:]
    model = joblib.load(f'model/baseline/{ver_folder}/LGB_base_{typee}.joblib')
    preds = model.predict(test_candidates[FEATURES])

    # Получение топ-20 предсказаний для каждой сессии и доп преобразования
    lv_predictions = test_candidates[['session', 'aid']].copy()
    lv_predictions['pred'] = preds
    lv_predictions = lv_predictions.sort_values(
        ['session', 'pred'], ascending=[True, False]).reset_index(drop=True)
    lv_predictions['n'] = lv_predictions.groupby(
        'session').aid.cumcount().astype('int8')
    lv_predictions = lv_predictions.loc[lv_predictions.n < 20]
    lv_predictions = lv_predictions.groupby('session').aid.apply(list)
    lv_predictions = lv_predictions.to_frame().reset_index()
    lv_predictions.rename(columns={'aid': 'labels'}, inplace=True)
    lv_predictions['type'] = typee

    # Объединение временного DataFrame с основным датасетом
    lv_predictions_full = pd.concat([lv_predictions_full, lv_predictions],
                                    ignore_index=True)
    del lv_predictions, preds, test_candidates

    # lv_predictions.to_parquet(f'lv_predictions_{typee}.parquet')
    # shutil.copy2(f'lv_predictions_{typee}.parquet', f'{main_path}/lv/{ver_folder}/lv_predictions_{typee}.parquet' )
# Out:
# type:   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:01<00:04,  1.16s/it]
#  40%|████      | 2/5 [00:04<00:07,  2.57s/it]
#  60%|██████    | 3/5 [00:08<00:06,  3.13s/it]
#  80%|████████  | 4/5 [00:12<00:03,  3.62s/it]
# 100%|██████████| 5/5 [00:17<00:00,  3.57s/it]
# type:  33%|███▎      | 1/3 [01:57<03:54, 117.34s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:03,  1.16it/s]
#  40%|████      | 2/5 [00:02<00:03,  1.23s/it]
#  60%|██████    | 3/5 [00:04<00:03,  1.52s/it]
#  80%|████████  | 4/5 [00:06<00:01,  1.89s/it]
# 100%|██████████| 5/5 [00:09<00:00,  1.90s/it]
# type:  67%|██████▋   | 2/3 [03:55<01:58, 118.02s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:03,  1.23it/s]
#  40%|████      | 2/5 [00:02<00:04,  1.35s/it]
#  60%|██████    | 3/5 [00:04<00:03,  1.60s/it]
#  80%|████████  | 4/5 [00:06<00:01,  1.92s/it]
# 100%|██████████| 5/5 [00:09<00:00,  1.91s/it]
# type: 100%|██████████| 3/3 [05:40<00:00, 113.36s/it]

# %%
id2type_name = 'id2type.pkl'
# version = 'ver_6.1'

# %%
valid = pd.read_parquet(f'{main_path}/s/test_labels_loc.parquet')

with open(f'{main_path}/pkl/{id2type_name}', 'rb') as file:
    id2type = pickle.load(file)

print('Model score :', metric_eval(lv_predictions_full, valid, id2type))
# Out:
# Model score : (0.5248555778378172, type
# carts     0.364534
# clicks    0.391417
# orders    0.627256
# dtype: float64)

# %%
best_score_base['lgbm'] = 0.5248555778378172
best_score_base
# Out:
# {'xgb': 0.5220552152693079, 'lgbm': 0.5248555778378172}

# %% [markdown]
# # Catboost Baseline

# %% [markdown]
# ## Тренировка

# %%
ver_folder = 'catb_base'
random_state = 42
# slice_value = 1
downsamp_k = 16

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.2-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.2

# %%
import catboost
from catboost import CatBoostRanker, Pool

# %%
import os
os.environ['CATBOOST_GPU'] = '1'

# %%
# Итерация по типам событий ('clicks', 'carts', 'orders')
for typee in tqdm(['clicks', 'carts', 'orders'], desc='type'):

    # Путь к данным тренировочных кандидатов выбранного типа
    path = f'{main_path}/tr/ver_6/tr_candidates_{typee}/*'

    # Чтение данных тренировочных кандидатов из Parquet-файлов
    tr_candidates = read_parquets(path)
    print('reading_done')

    # Приведение типов колонок 'session' и 'aid' к int32
    tr_candidates.session = tr_candidates.session.astype(np.int32)
    tr_candidates.aid = tr_candidates.aid.astype(np.int32)

    # Расчет соотношения классов
    class_ratio = tr_candidates['target'].value_counts(
    )[1] / tr_candidates['target'].value_counts()[0]

    # Указание желаемого соотношения классов для RandomUnderSampler
    under_sampler = RandomUnderSampler(sampling_strategy=class_ratio *
                                       downsamp_k)

    # Отбор признаков
    FEATURES = tr_candidates.columns[:-1]

    # Разделение на признаки и целевую переменную
    X = tr_candidates.loc[:, FEATURES]
    y = tr_candidates.loc[:, 'target']

    # Применение RandomUnderSampler для балансировки классов
    X_train, y_train = under_sampler.fit_resample(X, y)
    tr_candidates = pd.merge(X_train,
                             y_train,
                             left_index=True,
                             right_index=True)
    del X, y
    print('sampling_done')

    # Создание директории для сохранения моделей
    folder_path = f'model/baseline/{ver_folder}'
    os.makedirs(folder_path, exist_ok=True)

    # Сортировка и сброс индексов в тренировочных кандидатах
    tr_candidates = tr_candidates.sort_values('session')
    tr_candidates = tr_candidates.reset_index(drop=True)

    # Отбор признаков
    FEATURES = tr_candidates.columns[:-1]

    # Разделение на признаки и целевую переменную
    X_train = tr_candidates[FEATURES]
    y_train = tr_candidates['target']

    # Создание группы для CatBoostRanker
    group_id_tr = X_train.iloc[:, 0]

    # Удаление ненужной колонки 'session' для обучения
    X_train = X_train.iloc[:, 2:]

    # Создание Pool для CatBoost
    catboost_train = Pool(data=X_train, label=y_train, group_id=group_id_tr)

    # Инициализация и обучение CatBoostRanker
    ranker = CatBoostRanker(loss_function='PairLogit',
                            task_type='GPU',
                            random_state=42)
    ranker.fit(catboost_train, early_stopping_rounds=50)

    # Создание директории для сохранения моделей CatBoost
    folder_path = f'model/baseline/{ver_folder}'
    os.makedirs(folder_path, exist_ok=True)

    # Сохранение модели CatBoostRanker на диск
    ranker.save_model(f'model/baseline/{ver_folder}/catb_base_{typee}')
    print('training_done')
# Out:
# type:   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:05<00:23,  5.94s/it]
#  40%|████      | 2/5 [00:15<00:24,  8.17s/it]
#  60%|██████    | 3/5 [00:23<00:16,  8.07s/it]
#  80%|████████  | 4/5 [00:31<00:07,  7.85s/it]
# 100%|██████████| 5/5 [00:39<00:00,  7.94s/it]
# reading_done
# sampling_done
# 0:	learn: 0.6722801	total: 52.4ms	remaining: 52.3s
# 1:	learn: 0.6521243	total: 105ms	remaining: 52.6s
# 2:	learn: 0.6345881	total: 156ms	remaining: 51.8s
# 3:	learn: 0.6183704	total: 207ms	remaining: 51.6s
# 4:	learn: 0.6027706	total: 257ms	remaining: 51.2s
# 5:	learn: 0.5885391	total: 304ms	remaining: 50.4s
# 6:	learn: 0.5755264	total: 352ms	remaining: 49.9s
# 7:	learn: 0.5636078	total: 400ms	remaining: 49.6s
# 8:	learn: 0.5530807	total: 448ms	remaining: 49.4s
# 9:	learn: 0.5431993	total: 496ms	remaining: 49.1s
# 10:	learn: 0.5343235	total: 544ms	remaining: 49s
# 11:	learn: 0.5259114	total: 592ms	remaining: 48.8s
# 12:	learn: 0.5179888	total: 639ms	remaining: 48.5s
# 13:	learn: 0.5109231	total: 687ms	remaining: 48.4s
# 14:	learn: 0.5044133	total: 734ms	remaining: 48.2s
# 15:	learn: 0.4982586	total: 782ms	remaining: 48.1s
# 16:	learn: 0.4923669	total: 830ms	remaining: 48s
# 17:	learn: 0.4870210	total: 878ms	remaining: 47.9s
# 18:	learn: 0.4823054	total: 924ms	remaining: 47.7s
# 19:	learn: 0.4779880	total: 972ms	remaining: 47.6s
# 20:	learn: 0.4740213	total: 1.02s	remaining: 47.5s
# 21:	learn: 0.4697986	total: 1.06s	remaining: 47.4s
# 22:	learn: 0.4660568	total: 1.11s	remaining: 47.3s
# 23:	learn: 0.4629206	total: 1.16s	remaining: 47.2s
# 24:	learn: 0.4599803	total: 1.21s	remaining: 47.2s
# 25:	learn: 0.4570014	total: 1.26s	remaining: 47.1s
# 26:	learn: 0.4540364	total: 1.3s	remaining: 47s
# 27:	learn: 0.4514663	total: 1.35s	remaining: 47s
# 28:	learn: 0.4489841	total: 1.4s	remaining: 46.9s
# 29:	learn: 0.4469250	total: 1.45s	remaining: 46.8s
# 30:	learn: 0.4449061	total: 1.5s	remaining: 46.7s
# 31:	learn: 0.4428373	total: 1.54s	remaining: 46.6s
# 32:	learn: 0.4409035	total: 1.59s	remaining: 46.5s
# 33:	learn: 0.4392577	total: 1.64s	remaining: 46.5s
# 34:	learn: 0.4378045	total: 1.68s	remaining: 46.4s
# 35:	learn: 0.4361348	total: 1.73s	remaining: 46.3s
# 36:	learn: 0.4347766	total: 1.78s	remaining: 46.2s
# 37:	learn: 0.4333033	total: 1.82s	remaining: 46.2s
# 38:	learn: 0.4321962	total: 1.87s	remaining: 46.1s
# 39:	learn: 0.4309203	total: 1.92s	remaining: 46.1s
# 40:	learn: 0.4298894	total: 1.97s	remaining: 46s
# 41:	learn: 0.4287782	total: 2.01s	remaining: 45.9s
# 42:	learn: 0.4276496	total: 2.06s	remaining: 45.8s
# 43:	learn: 0.4266634	total: 2.11s	remaining: 45.8s
# 44:	learn: 0.4259677	total: 2.15s	remaining: 45.7s
# 45:	learn: 0.4250349	total: 2.2s	remaining: 45.7s
# 46:	learn: 0.4241662	total: 2.25s	remaining: 45.6s
# 47:	learn: 0.4233441	total: 2.3s	remaining: 45.6s
# 48:	learn: 0.4225137	total: 2.35s	remaining: 45.6s
# 49:	learn: 0.4219112	total: 2.4s	remaining: 45.5s
# 50:	learn: 0.4212637	total: 2.44s	remaining: 45.5s
# 51:	learn: 0.4206229	total: 2.49s	remaining: 45.4s
# 52:	learn: 0.4201290	total: 2.54s	remaining: 45.4s
# 53:	learn: 0.4195715	total: 2.59s	remaining: 45.4s
# 54:	learn: 0.4190256	total: 2.64s	remaining: 45.3s
# 55:	learn: 0.4184603	total: 2.69s	remaining: 45.3s
# 56:	learn: 0.4179169	total: 2.73s	remaining: 45.2s
# 57:	learn: 0.4174427	total: 2.78s	remaining: 45.2s
# 58:	learn: 0.4169964	total: 2.83s	remaining: 45.1s
# 59:	learn: 0.4164883	total: 2.88s	remaining: 45.1s
# 60:	learn: 0.4161383	total: 2.92s	remaining: 45s
# 61:	learn: 0.4158474	total: 2.97s	remaining: 45s
# 62:	learn: 0.4153759	total: 3.02s	remaining: 45s
# 63:	learn: 0.4148719	total: 3.07s	remaining: 44.9s
# 64:	learn: 0.4144572	total: 3.12s	remaining: 44.8s
# 65:	learn: 0.4140332	total: 3.17s	remaining: 44.8s
# 66:	learn: 0.4137803	total: 3.21s	remaining: 44.7s
# 67:	learn: 0.4135367	total: 3.26s	remaining: 44.7s
# 68:	learn: 0.4131852	total: 3.31s	remaining: 44.7s
# 69:	learn: 0.4128638	total: 3.36s	remaining: 44.6s
# 70:	learn: 0.4124891	total: 3.4s	remaining: 44.5s
# 71:	learn: 0.4122469	total: 3.45s	remaining: 44.5s
# 72:	learn: 0.4120276	total: 3.5s	remaining: 44.5s
# 73:	learn: 0.4117694	total: 3.55s	remaining: 44.4s
# 74:	learn: 0.4114604	total: 3.59s	remaining: 44.3s
# 75:	learn: 0.4111494	total: 3.64s	remaining: 44.2s
# 76:	learn: 0.4109518	total: 3.69s	remaining: 44.2s
# 77:	learn: 0.4106982	total: 3.73s	remaining: 44.1s
# 78:	learn: 0.4104979	total: 3.78s	remaining: 44.1s
# 79:	learn: 0.4103427	total: 3.83s	remaining: 44.1s
# 80:	learn: 0.4101084	total: 3.88s	remaining: 44s
# 81:	learn: 0.4099420	total: 3.92s	remaining: 43.9s
# 82:	learn: 0.4097004	total: 3.97s	remaining: 43.9s
# 83:	learn: 0.4095535	total: 4.02s	remaining: 43.9s
# 84:	learn: 0.4093903	total: 4.07s	remaining: 43.8s
# 85:	learn: 0.4091829	total: 4.12s	remaining: 43.8s
# 86:	learn: 0.4089388	total: 4.17s	remaining: 43.7s
# 87:	learn: 0.4087959	total: 4.22s	remaining: 43.7s
# 88:	learn: 0.4086093	total: 4.26s	remaining: 43.6s
# 89:	learn: 0.4084122	total: 4.31s	remaining: 43.6s
# 90:	learn: 0.4082870	total: 4.36s	remaining: 43.5s
# 91:	learn: 0.4081534	total: 4.41s	remaining: 43.5s
# 92:	learn: 0.4079831	total: 4.45s	remaining: 43.4s
# 93:	learn: 0.4078282	total: 4.5s	remaining: 43.4s
# 94:	learn: 0.4076841	total: 4.55s	remaining: 43.4s
# 95:	learn: 0.4075686	total: 4.6s	remaining: 43.4s
# 96:	learn: 0.4074528	total: 4.66s	remaining: 43.3s
# 97:	learn: 0.4073352	total: 4.71s	remaining: 43.3s
# 98:	learn: 0.4072323	total: 4.76s	remaining: 43.3s
# 99:	learn: 0.4071126	total: 4.81s	remaining: 43.3s
# 100:	learn: 0.4070035	total: 4.85s	remaining: 43.2s
# 101:	learn: 0.4069077	total: 4.9s	remaining: 43.2s
# 102:	learn: 0.4067281	total: 4.95s	remaining: 43.1s
# 103:	learn: 0.4066127	total: 5s	remaining: 43.1s
# 104:	learn: 0.4064537	total: 5.05s	remaining: 43s
# 105:	learn: 0.4062957	total: 5.1s	remaining: 43s
# 106:	learn: 0.4062140	total: 5.15s	remaining: 43s
# 107:	learn: 0.4061348	total: 5.2s	remaining: 42.9s
# 108:	learn: 0.4059959	total: 5.25s	remaining: 42.9s
# 109:	learn: 0.4058610	total: 5.3s	remaining: 42.9s
# 110:	learn: 0.4057839	total: 5.35s	remaining: 42.8s
# 111:	learn: 0.4057088	total: 5.4s	remaining: 42.8s
# 112:	learn: 0.4055745	total: 5.45s	remaining: 42.7s
# 113:	learn: 0.4054775	total: 5.49s	remaining: 42.7s
# 114:	learn: 0.4053879	total: 5.54s	remaining: 42.7s
# 115:	learn: 0.4053063	total: 5.59s	remaining: 42.6s
# 116:	learn: 0.4051880	total: 5.65s	remaining: 42.6s
# 117:	learn: 0.4051055	total: 5.7s	remaining: 42.6s
# 118:	learn: 0.4050210	total: 5.75s	remaining: 42.5s
# 119:	learn: 0.4049198	total: 5.79s	remaining: 42.5s
# 120:	learn: 0.4048008	total: 5.84s	remaining: 42.4s
# 121:	learn: 0.4047029	total: 5.89s	remaining: 42.4s
# 122:	learn: 0.4046410	total: 5.94s	remaining: 42.4s
# 123:	learn: 0.4045467	total: 5.99s	remaining: 42.4s
# 124:	learn: 0.4044401	total: 6.04s	remaining: 42.3s
# 125:	learn: 0.4043572	total: 6.09s	remaining: 42.3s
# 126:	learn: 0.4042956	total: 6.14s	remaining: 42.2s
# 127:	learn: 0.4041883	total: 6.19s	remaining: 42.2s
# 128:	learn: 0.4041255	total: 6.24s	remaining: 42.1s
# 129:	learn: 0.4040746	total: 6.29s	remaining: 42.1s
# 130:	learn: 0.4040122	total: 6.34s	remaining: 42.1s
# 131:	learn: 0.4039548	total: 6.39s	remaining: 42s
# 132:	learn: 0.4038872	total: 6.44s	remaining: 42s
# 133:	learn: 0.4038059	total: 6.48s	remaining: 41.9s
# 134:	learn: 0.4037270	total: 6.53s	remaining: 41.9s
# 135:	learn: 0.4036577	total: 6.58s	remaining: 41.8s
# 136:	learn: 0.4035750	total: 6.63s	remaining: 41.8s
# 137:	learn: 0.4035136	total: 6.68s	remaining: 41.8s
# 138:	learn: 0.4034693	total: 6.73s	remaining: 41.7s
# 139:	learn: 0.4034107	total: 6.78s	remaining: 41.7s
# 140:	learn: 0.4033639	total: 6.83s	remaining: 41.6s
# 141:	learn: 0.4033217	total: 6.88s	remaining: 41.6s
# 142:	learn: 0.4032494	total: 6.93s	remaining: 41.5s
# 143:	learn: 0.4032098	total: 6.98s	remaining: 41.5s
# 144:	learn: 0.4031558	total: 7.03s	remaining: 41.5s
# 145:	learn: 0.4030871	total: 7.08s	remaining: 41.4s
# 146:	learn: 0.4030097	total: 7.12s	remaining: 41.3s
# 147:	learn: 0.4029261	total: 7.17s	remaining: 41.3s
# 148:	learn: 0.4028708	total: 7.22s	remaining: 41.2s
# 149:	learn: 0.4027913	total: 7.27s	remaining: 41.2s
# 150:	learn: 0.4027484	total: 7.32s	remaining: 41.2s
# 151:	learn: 0.4026772	total: 7.37s	remaining: 41.1s
# 152:	learn: 0.4026377	total: 7.42s	remaining: 41.1s
# 153:	learn: 0.4025868	total: 7.46s	remaining: 41s
# 154:	learn: 0.4025366	total: 7.51s	remaining: 41s
# 155:	learn: 0.4024576	total: 7.56s	remaining: 40.9s
# 156:	learn: 0.4023957	total: 7.61s	remaining: 40.9s
# 157:	learn: 0.4023573	total: 7.66s	remaining: 40.8s
# 158:	learn: 0.4023154	total: 7.71s	remaining: 40.8s
# 159:	learn: 0.4022756	total: 7.76s	remaining: 40.8s
# 160:	learn: 0.4022334	total: 7.82s	remaining: 40.7s
# 161:	learn: 0.4021957	total: 7.87s	remaining: 40.7s
# 162:	learn: 0.4021557	total: 7.92s	remaining: 40.6s
# 163:	learn: 0.4020961	total: 7.96s	remaining: 40.6s
# 164:	learn: 0.4020267	total: 8.01s	remaining: 40.5s
# 165:	learn: 0.4019848	total: 8.06s	remaining: 40.5s
# 166:	learn: 0.4019394	total: 8.11s	remaining: 40.4s
# 167:	learn: 0.4018938	total: 8.15s	remaining: 40.4s
# 168:	learn: 0.4018568	total: 8.21s	remaining: 40.4s
# 169:	learn: 0.4017786	total: 8.26s	remaining: 40.3s
# 170:	learn: 0.4017482	total: 8.31s	remaining: 40.3s
# 171:	learn: 0.4016849	total: 8.36s	remaining: 40.2s
# 172:	learn: 0.4016443	total: 8.4s	remaining: 40.2s
# 173:	learn: 0.4016062	total: 8.45s	remaining: 40.1s
# 174:	learn: 0.4015652	total: 8.5s	remaining: 40.1s
# 175:	learn: 0.4015354	total: 8.55s	remaining: 40.1s
# 176:	learn: 0.4015024	total: 8.61s	remaining: 40s
# 177:	learn: 0.4014545	total: 8.66s	remaining: 40s
# 178:	learn: 0.4014349	total: 8.71s	remaining: 39.9s
# 179:	learn: 0.4013823	total: 8.76s	remaining: 39.9s
# 180:	learn: 0.4013516	total: 8.81s	remaining: 39.9s
# 181:	learn: 0.4013095	total: 8.86s	remaining: 39.8s
# 182:	learn: 0.4012662	total: 8.91s	remaining: 39.8s
# 183:	learn: 0.4012237	total: 8.96s	remaining: 39.7s
# 184:	learn: 0.4011646	total: 9.01s	remaining: 39.7s
# 185:	learn: 0.4011206	total: 9.05s	remaining: 39.6s
# 186:	learn: 0.4010830	total: 9.1s	remaining: 39.6s
# 187:	learn: 0.4010380	total: 9.15s	remaining: 39.5s
# 188:	learn: 0.4009993	total: 9.2s	remaining: 39.5s
# 189:	learn: 0.4009570	total: 9.25s	remaining: 39.4s
# 190:	learn: 0.4009205	total: 9.3s	remaining: 39.4s
# 191:	learn: 0.4008919	total: 9.35s	remaining: 39.3s
# 192:	learn: 0.4008694	total: 9.4s	remaining: 39.3s
# 193:	learn: 0.4008361	total: 9.45s	remaining: 39.3s
# 194:	learn: 0.4008117	total: 9.5s	remaining: 39.2s
# 195:	learn: 0.4007671	total: 9.55s	remaining: 39.2s
# 196:	learn: 0.4007430	total: 9.61s	remaining: 39.2s
# 197:	learn: 0.4006919	total: 9.65s	remaining: 39.1s
# 198:	learn: 0.4006678	total: 9.71s	remaining: 39.1s
# 199:	learn: 0.4006281	total: 9.76s	remaining: 39s
# 200:	learn: 0.4006055	total: 9.81s	remaining: 39s
# 201:	learn: 0.4005794	total: 9.86s	remaining: 39s
# 202:	learn: 0.4005391	total: 9.91s	remaining: 38.9s
# 203:	learn: 0.4005064	total: 9.96s	remaining: 38.9s
# 204:	learn: 0.4004708	total: 10s	remaining: 38.8s
# 205:	learn: 0.4004363	total: 10.1s	remaining: 38.8s
# 206:	learn: 0.4004116	total: 10.1s	remaining: 38.7s
# 207:	learn: 0.4003773	total: 10.2s	remaining: 38.7s
# 208:	learn: 0.4003398	total: 10.2s	remaining: 38.6s
# 209:	learn: 0.4003020	total: 10.3s	remaining: 38.6s
# 210:	learn: 0.4002821	total: 10.3s	remaining: 38.5s
# 211:	learn: 0.4002597	total: 10.4s	remaining: 38.5s
# 212:	learn: 0.4002345	total: 10.4s	remaining: 38.5s
# 213:	learn: 0.4001923	total: 10.5s	remaining: 38.4s
# 214:	learn: 0.4001636	total: 10.5s	remaining: 38.3s
# 215:	learn: 0.4001361	total: 10.5s	remaining: 38.3s
# 216:	learn: 0.4001064	total: 10.6s	remaining: 38.2s
# 217:	learn: 0.4000576	total: 10.6s	remaining: 38.2s
# 218:	learn: 0.4000199	total: 10.7s	remaining: 38.1s
# 219:	learn: 0.3999886	total: 10.7s	remaining: 38.1s
# 220:	learn: 0.3999649	total: 10.8s	remaining: 38.1s
# 221:	learn: 0.3999425	total: 10.8s	remaining: 38s
# 222:	learn: 0.3999110	total: 10.9s	remaining: 38s
# 223:	learn: 0.3998905	total: 10.9s	remaining: 37.9s
# 224:	learn: 0.3998605	total: 11s	remaining: 37.9s
# 225:	learn: 0.3998285	total: 11s	remaining: 37.8s
# 226:	learn: 0.3998087	total: 11.1s	remaining: 37.8s
# 227:	learn: 0.3997926	total: 11.1s	remaining: 37.8s
# 228:	learn: 0.3997630	total: 11.2s	remaining: 37.7s
# 229:	learn: 0.3997441	total: 11.2s	remaining: 37.7s
# 230:	learn: 0.3997139	total: 11.3s	remaining: 37.6s
# 231:	learn: 0.3996841	total: 11.3s	remaining: 37.5s
# 232:	learn: 0.3996615	total: 11.4s	remaining: 37.5s
# 233:	learn: 0.3996411	total: 11.4s	remaining: 37.4s
# 234:	learn: 0.3996140	total: 11.5s	remaining: 37.4s
# 235:	learn: 0.3995942	total: 11.5s	remaining: 37.4s
# 236:	learn: 0.3995756	total: 11.6s	remaining: 37.3s
# 237:	learn: 0.3995555	total: 11.6s	remaining: 37.3s
# 238:	learn: 0.3995364	total: 11.7s	remaining: 37.2s
# 239:	learn: 0.3995208	total: 11.7s	remaining: 37.2s
# 240:	learn: 0.3994942	total: 11.8s	remaining: 37.1s
# 241:	learn: 0.3994694	total: 11.8s	remaining: 37.1s
# 242:	learn: 0.3994353	total: 11.9s	remaining: 37s
# 243:	learn: 0.3994209	total: 11.9s	remaining: 37s
# 244:	learn: 0.3994008	total: 12s	remaining: 37s
# 245:	learn: 0.3993787	total: 12s	remaining: 36.9s
# 246:	learn: 0.3993602	total: 12.1s	remaining: 36.9s
# 247:	learn: 0.3993490	total: 12.1s	remaining: 36.8s
# 248:	learn: 0.3993330	total: 12.2s	remaining: 36.8s
# 249:	learn: 0.3993153	total: 12.2s	remaining: 36.7s
# 250:	learn: 0.3992945	total: 12.3s	remaining: 36.7s
# 251:	learn: 0.3992765	total: 12.4s	remaining: 36.7s
# 252:	learn: 0.3992594	total: 12.4s	remaining: 36.6s
# 253:	learn: 0.3992414	total: 12.5s	remaining: 36.6s
# 254:	learn: 0.3992195	total: 12.5s	remaining: 36.5s
# 255:	learn: 0.3992052	total: 12.6s	remaining: 36.5s
# 256:	learn: 0.3991861	total: 12.6s	remaining: 36.4s
# 257:	learn: 0.3991770	total: 12.7s	remaining: 36.4s
# 258:	learn: 0.3991514	total: 12.7s	remaining: 36.3s
# 259:	learn: 0.3991353	total: 12.8s	remaining: 36.3s
# 260:	learn: 0.3991108	total: 12.8s	remaining: 36.2s
# 261:	learn: 0.3990919	total: 12.9s	remaining: 36.2s
# 262:	learn: 0.3990767	total: 12.9s	remaining: 36.2s
# 263:	learn: 0.3990499	total: 13s	remaining: 36.1s
# 264:	learn: 0.3990347	total: 13s	remaining: 36.1s
# 265:	learn: 0.3990148	total: 13.1s	remaining: 36s
# 266:	learn: 0.3989964	total: 13.1s	remaining: 36s
# 267:	learn: 0.3989754	total: 13.2s	remaining: 35.9s
# 268:	learn: 0.3989618	total: 13.2s	remaining: 35.9s
# 269:	learn: 0.3989371	total: 13.3s	remaining: 35.8s
# 270:	learn: 0.3989236	total: 13.3s	remaining: 35.8s
# 271:	learn: 0.3989125	total: 13.4s	remaining: 35.7s
# 272:	learn: 0.3988964	total: 13.4s	remaining: 35.7s
# 273:	learn: 0.3988733	total: 13.4s	remaining: 35.6s
# 274:	learn: 0.3988484	total: 13.5s	remaining: 35.6s
# 275:	learn: 0.3988230	total: 13.5s	remaining: 35.5s
# 276:	learn: 0.3988067	total: 13.6s	remaining: 35.5s
# 277:	learn: 0.3987855	total: 13.6s	remaining: 35.4s
# 278:	learn: 0.3987778	total: 13.7s	remaining: 35.4s
# 279:	learn: 0.3987660	total: 13.7s	remaining: 35.3s
# 280:	learn: 0.3987492	total: 13.8s	remaining: 35.3s
# 281:	learn: 0.3987228	total: 13.8s	remaining: 35.3s
# 282:	learn: 0.3987103	total: 13.9s	remaining: 35.2s
# 283:	learn: 0.3986880	total: 13.9s	remaining: 35.2s
# 284:	learn: 0.3986733	total: 14s	remaining: 35.1s
# 285:	learn: 0.3986402	total: 14s	remaining: 35.1s
# 286:	learn: 0.3986215	total: 14.1s	remaining: 35s
# 287:	learn: 0.3986085	total: 14.1s	remaining: 35s
# 288:	learn: 0.3985953	total: 14.2s	remaining: 34.9s
# 289:	learn: 0.3985837	total: 14.2s	remaining: 34.9s
# 290:	learn: 0.3985647	total: 14.3s	remaining: 34.8s
# 291:	learn: 0.3985516	total: 14.3s	remaining: 34.8s
# 292:	learn: 0.3985327	total: 14.4s	remaining: 34.7s
# 293:	learn: 0.3985121	total: 14.4s	remaining: 34.7s
# 294:	learn: 0.3984990	total: 14.5s	remaining: 34.6s
# 295:	learn: 0.3984862	total: 14.5s	remaining: 34.6s
# 296:	learn: 0.3984720	total: 14.6s	remaining: 34.5s
# 297:	learn: 0.3984523	total: 14.6s	remaining: 34.5s
# 298:	learn: 0.3984152	total: 14.7s	remaining: 34.4s
# 299:	learn: 0.3983991	total: 14.7s	remaining: 34.4s
# 300:	learn: 0.3983868	total: 14.8s	remaining: 34.4s
# 301:	learn: 0.3983719	total: 14.8s	remaining: 34.3s
# 302:	learn: 0.3983516	total: 14.9s	remaining: 34.2s
# 303:	learn: 0.3983405	total: 14.9s	remaining: 34.2s
# 304:	learn: 0.3983255	total: 15s	remaining: 34.1s
# 305:	learn: 0.3983142	total: 15s	remaining: 34.1s
# 306:	learn: 0.3983031	total: 15.1s	remaining: 34s
# 307:	learn: 0.3982864	total: 15.1s	remaining: 34s
# 308:	learn: 0.3982772	total: 15.2s	remaining: 34s
# 309:	learn: 0.3982562	total: 15.2s	remaining: 33.9s
# 310:	learn: 0.3982435	total: 15.3s	remaining: 33.9s
# 311:	learn: 0.3982343	total: 15.3s	remaining: 33.8s
# 312:	learn: 0.3982241	total: 15.4s	remaining: 33.8s
# 313:	learn: 0.3982119	total: 15.4s	remaining: 33.7s
# 314:	learn: 0.3981844	total: 15.5s	remaining: 33.7s
# 315:	learn: 0.3981649	total: 15.5s	remaining: 33.6s
# 316:	learn: 0.3981574	total: 15.6s	remaining: 33.6s
# 317:	learn: 0.3981422	total: 15.6s	remaining: 33.5s
# 318:	learn: 0.3981253	total: 15.7s	remaining: 33.5s
# 319:	learn: 0.3981059	total: 15.7s	remaining: 33.4s
# 320:	learn: 0.3980939	total: 15.8s	remaining: 33.4s
# 321:	learn: 0.3980846	total: 15.8s	remaining: 33.3s
# 322:	learn: 0.3980733	total: 15.9s	remaining: 33.3s
# 323:	learn: 0.3980403	total: 15.9s	remaining: 33.2s
# 324:	learn: 0.3980296	total: 16s	remaining: 33.2s
# 325:	learn: 0.3980150	total: 16s	remaining: 33.1s
# 326:	learn: 0.3980047	total: 16.1s	remaining: 33.1s
# 327:	learn: 0.3979887	total: 16.1s	remaining: 33s
# 328:	learn: 0.3979753	total: 16.2s	remaining: 33s
# 329:	learn: 0.3979582	total: 16.2s	remaining: 32.9s
# 330:	learn: 0.3979447	total: 16.3s	remaining: 32.9s
# 331:	learn: 0.3979261	total: 16.3s	remaining: 32.8s
# 332:	learn: 0.3979076	total: 16.4s	remaining: 32.8s
# 333:	learn: 0.3978971	total: 16.4s	remaining: 32.7s
# 334:	learn: 0.3978745	total: 16.5s	remaining: 32.7s
# 335:	learn: 0.3978640	total: 16.5s	remaining: 32.6s
# 336:	learn: 0.3978508	total: 16.6s	remaining: 32.6s
# 337:	learn: 0.3978461	total: 16.6s	remaining: 32.5s
# 338:	learn: 0.3978316	total: 16.7s	remaining: 32.5s
# 339:	learn: 0.3978166	total: 16.7s	remaining: 32.4s
# 340:	learn: 0.3978042	total: 16.8s	remaining: 32.4s
# 341:	learn: 0.3977874	total: 16.8s	remaining: 32.3s
# 342:	learn: 0.3977758	total: 16.9s	remaining: 32.3s
# 343:	learn: 0.3977647	total: 16.9s	remaining: 32.2s
# 344:	learn: 0.3977488	total: 16.9s	remaining: 32.2s
# 345:	learn: 0.3977379	total: 17s	remaining: 32.1s
# 346:	learn: 0.3977278	total: 17s	remaining: 32.1s
# 347:	learn: 0.3977214	total: 17.1s	remaining: 32s
# 348:	learn: 0.3977121	total: 17.2s	remaining: 32s
# 349:	learn: 0.3976956	total: 17.2s	remaining: 31.9s
# 350:	learn: 0.3976875	total: 17.3s	remaining: 31.9s
# 351:	learn: 0.3976830	total: 17.3s	remaining: 31.9s
# 352:	learn: 0.3976703	total: 17.4s	remaining: 31.8s
# 353:	learn: 0.3976574	total: 17.4s	remaining: 31.8s
# 354:	learn: 0.3976456	total: 17.5s	remaining: 31.7s
# 355:	learn: 0.3976331	total: 17.5s	remaining: 31.7s
# 356:	learn: 0.3975939	total: 17.5s	remaining: 31.6s
# 357:	learn: 0.3975837	total: 17.6s	remaining: 31.6s
# 358:	learn: 0.3975754	total: 17.7s	remaining: 31.5s
# 359:	learn: 0.3975661	total: 17.7s	remaining: 31.5s
# 360:	learn: 0.3975460	total: 17.8s	remaining: 31.4s
# 361:	learn: 0.3975374	total: 17.8s	remaining: 31.4s
# 362:	learn: 0.3975257	total: 17.9s	remaining: 31.3s
# 363:	learn: 0.3975204	total: 17.9s	remaining: 31.3s
# 364:	learn: 0.3975100	total: 18s	remaining: 31.2s
# 365:	learn: 0.3974963	total: 18s	remaining: 31.2s
# 366:	learn: 0.3974834	total: 18.1s	remaining: 31.1s
# 367:	learn: 0.3974759	total: 18.1s	remaining: 31.1s
# 368:	learn: 0.3974624	total: 18.2s	remaining: 31s
# 369:	learn: 0.3974551	total: 18.2s	remaining: 31s
# 370:	learn: 0.3974435	total: 18.3s	remaining: 31s
# 371:	learn: 0.3974250	total: 18.3s	remaining: 30.9s
# 372:	learn: 0.3974159	total: 18.4s	remaining: 30.9s
# 373:	learn: 0.3974044	total: 18.4s	remaining: 30.8s
# 374:	learn: 0.3973777	total: 18.5s	remaining: 30.8s
# 375:	learn: 0.3973706	total: 18.5s	remaining: 30.7s
# 376:	learn: 0.3973627	total: 18.5s	remaining: 30.7s
# 377:	learn: 0.3973496	total: 18.6s	remaining: 30.6s
# 378:	learn: 0.3973375	total: 18.7s	remaining: 30.6s
# 379:	learn: 0.3973298	total: 18.7s	remaining: 30.5s
# 380:	learn: 0.3973156	total: 18.8s	remaining: 30.5s
# 381:	learn: 0.3973078	total: 18.8s	remaining: 30.4s
# 382:	learn: 0.3972969	total: 18.9s	remaining: 30.4s
# 383:	learn: 0.3972911	total: 18.9s	remaining: 30.3s
# 384:	learn: 0.3972808	total: 19s	remaining: 30.3s
# 385:	learn: 0.3972701	total: 19s	remaining: 30.2s
# 386:	learn: 0.3972607	total: 19.1s	remaining: 30.2s
# 387:	learn: 0.3972531	total: 19.1s	remaining: 30.1s
# 388:	learn: 0.3972419	total: 19.2s	remaining: 30.1s
# 389:	learn: 0.3972275	total: 19.2s	remaining: 30s
# 390:	learn: 0.3972165	total: 19.3s	remaining: 30s
# 391:	learn: 0.3972083	total: 19.3s	remaining: 29.9s
# 392:	learn: 0.3972008	total: 19.4s	remaining: 29.9s
# 393:	learn: 0.3971829	total: 19.4s	remaining: 29.8s
# 394:	learn: 0.3971730	total: 19.5s	remaining: 29.8s
# 395:	learn: 0.3971640	total: 19.5s	remaining: 29.8s
# 396:	learn: 0.3971414	total: 19.6s	remaining: 29.7s
# 397:	learn: 0.3971323	total: 19.6s	remaining: 29.6s
# 398:	learn: 0.3971281	total: 19.6s	remaining: 29.6s
# 399:	learn: 0.3971102	total: 19.7s	remaining: 29.5s
# 400:	learn: 0.3971042	total: 19.7s	remaining: 29.5s
# 401:	learn: 0.3970941	total: 19.8s	remaining: 29.4s
# 402:	learn: 0.3970851	total: 19.8s	remaining: 29.4s
# 403:	learn: 0.3970595	total: 19.9s	remaining: 29.4s
# 404:	learn: 0.3970508	total: 19.9s	remaining: 29.3s
# 405:	learn: 0.3970456	total: 20s	remaining: 29.3s
# 406:	learn: 0.3970414	total: 20.1s	remaining: 29.2s
# 407:	learn: 0.3970330	total: 20.1s	remaining: 29.2s
# 408:	learn: 0.3970211	total: 20.2s	remaining: 29.1s
# 409:	learn: 0.3970085	total: 20.2s	remaining: 29.1s
# 410:	learn: 0.3969988	total: 20.2s	remaining: 29s
# 411:	learn: 0.3969863	total: 20.3s	remaining: 29s
# 412:	learn: 0.3969745	total: 20.3s	remaining: 28.9s
# 413:	learn: 0.3969655	total: 20.4s	remaining: 28.9s
# 414:	learn: 0.3969557	total: 20.4s	remaining: 28.8s
# 415:	learn: 0.3969460	total: 20.5s	remaining: 28.8s
# 416:	learn: 0.3969407	total: 20.5s	remaining: 28.7s
# 417:	learn: 0.3969320	total: 20.6s	remaining: 28.7s
# 418:	learn: 0.3969256	total: 20.6s	remaining: 28.6s
# 419:	learn: 0.3969206	total: 20.7s	remaining: 28.6s
# 420:	learn: 0.3969077	total: 20.7s	remaining: 28.5s
# 421:	learn: 0.3968990	total: 20.8s	remaining: 28.5s
# 422:	learn: 0.3968917	total: 20.8s	remaining: 28.4s
# 423:	learn: 0.3968858	total: 20.9s	remaining: 28.4s
# 424:	learn: 0.3968792	total: 20.9s	remaining: 28.3s
# 425:	learn: 0.3968675	total: 21s	remaining: 28.3s
# 426:	learn: 0.3968616	total: 21s	remaining: 28.2s
# 427:	learn: 0.3968464	total: 21.1s	remaining: 28.2s
# 428:	learn: 0.3968382	total: 21.1s	remaining: 28.1s
# 429:	learn: 0.3968290	total: 21.2s	remaining: 28.1s
# 430:	learn: 0.3968196	total: 21.2s	remaining: 28s
# 431:	learn: 0.3968123	total: 21.3s	remaining: 28s
# 432:	learn: 0.3968041	total: 21.3s	remaining: 27.9s
# 433:	learn: 0.3967946	total: 21.4s	remaining: 27.9s
# 434:	learn: 0.3967851	total: 21.4s	remaining: 27.8s
# 435:	learn: 0.3967759	total: 21.5s	remaining: 27.8s
# 436:	learn: 0.3967678	total: 21.5s	remaining: 27.7s
# 437:	learn: 0.3967637	total: 21.6s	remaining: 27.7s
# 438:	learn: 0.3967575	total: 21.6s	remaining: 27.6s
# 439:	learn: 0.3967480	total: 21.7s	remaining: 27.6s
# 440:	learn: 0.3967409	total: 21.7s	remaining: 27.6s
# 441:	learn: 0.3967327	total: 21.8s	remaining: 27.5s
# 442:	learn: 0.3967246	total: 21.8s	remaining: 27.5s
# 443:	learn: 0.3967109	total: 21.9s	remaining: 27.4s
# 444:	learn: 0.3966988	total: 21.9s	remaining: 27.4s
# 445:	learn: 0.3966907	total: 22s	remaining: 27.3s
# 446:	learn: 0.3966809	total: 22s	remaining: 27.3s
# 447:	learn: 0.3966729	total: 22.1s	remaining: 27.2s
# 448:	learn: 0.3966659	total: 22.1s	remaining: 27.2s
# 449:	learn: 0.3966603	total: 22.2s	remaining: 27.1s
# 450:	learn: 0.3966545	total: 22.2s	remaining: 27.1s
# 451:	learn: 0.3966439	total: 22.3s	remaining: 27s
# 452:	learn: 0.3966367	total: 22.3s	remaining: 27s
# 453:	learn: 0.3966331	total: 22.4s	remaining: 26.9s
# 454:	learn: 0.3966263	total: 22.4s	remaining: 26.9s
# 455:	learn: 0.3966199	total: 22.5s	remaining: 26.8s
# 456:	learn: 0.3966134	total: 22.5s	remaining: 26.8s
# 457:	learn: 0.3966074	total: 22.6s	remaining: 26.7s
# 458:	learn: 0.3965959	total: 22.6s	remaining: 26.7s
# 459:	learn: 0.3965880	total: 22.7s	remaining: 26.6s
# 460:	learn: 0.3965788	total: 22.7s	remaining: 26.6s
# 461:	learn: 0.3965728	total: 22.8s	remaining: 26.5s
# 462:	learn: 0.3965653	total: 22.8s	remaining: 26.5s
# 463:	learn: 0.3965559	total: 22.9s	remaining: 26.4s
# 464:	learn: 0.3965514	total: 22.9s	remaining: 26.4s
# 465:	learn: 0.3965437	total: 23s	remaining: 26.3s
# 466:	learn: 0.3965372	total: 23s	remaining: 26.3s
# 467:	learn: 0.3965317	total: 23.1s	remaining: 26.2s
# 468:	learn: 0.3965234	total: 23.1s	remaining: 26.2s
# 469:	learn: 0.3965140	total: 23.2s	remaining: 26.1s
# 470:	learn: 0.3965044	total: 23.2s	remaining: 26.1s
# 471:	learn: 0.3964959	total: 23.3s	remaining: 26s
# 472:	learn: 0.3964812	total: 23.3s	remaining: 26s
# 473:	learn: 0.3964718	total: 23.4s	remaining: 25.9s
# 474:	learn: 0.3964667	total: 23.4s	remaining: 25.9s
# 475:	learn: 0.3964619	total: 23.5s	remaining: 25.8s
# 476:	learn: 0.3964546	total: 23.5s	remaining: 25.8s
# 477:	learn: 0.3964489	total: 23.6s	remaining: 25.7s
# 478:	learn: 0.3964445	total: 23.6s	remaining: 25.7s
# 479:	learn: 0.3964362	total: 23.7s	remaining: 25.6s
# 480:	learn: 0.3964309	total: 23.7s	remaining: 25.6s
# 481:	learn: 0.3964230	total: 23.8s	remaining: 25.5s
# 482:	learn: 0.3964121	total: 23.8s	remaining: 25.5s
# 483:	learn: 0.3964079	total: 23.9s	remaining: 25.4s
# 484:	learn: 0.3964010	total: 23.9s	remaining: 25.4s
# 485:	learn: 0.3963973	total: 24s	remaining: 25.3s
# 486:	learn: 0.3963863	total: 24s	remaining: 25.3s
# 487:	learn: 0.3963822	total: 24.1s	remaining: 25.3s
# 488:	learn: 0.3963763	total: 24.1s	remaining: 25.2s
# 489:	learn: 0.3963675	total: 24.2s	remaining: 25.2s
# 490:	learn: 0.3963609	total: 24.2s	remaining: 25.1s
# 491:	learn: 0.3963474	total: 24.3s	remaining: 25.1s
# 492:	learn: 0.3963432	total: 24.3s	remaining: 25s
# 493:	learn: 0.3963336	total: 24.4s	remaining: 25s
# 494:	learn: 0.3963282	total: 24.4s	remaining: 24.9s
# 495:	learn: 0.3963136	total: 24.5s	remaining: 24.9s
# 496:	learn: 0.3963078	total: 24.5s	remaining: 24.8s
# 497:	learn: 0.3963000	total: 24.6s	remaining: 24.8s
# 498:	learn: 0.3962955	total: 24.6s	remaining: 24.7s
# 499:	learn: 0.3962859	total: 24.7s	remaining: 24.7s
# 500:	learn: 0.3962781	total: 24.7s	remaining: 24.6s
# 501:	learn: 0.3962651	total: 24.8s	remaining: 24.6s
# 502:	learn: 0.3962607	total: 24.8s	remaining: 24.5s
# 503:	learn: 0.3962520	total: 24.9s	remaining: 24.5s
# 504:	learn: 0.3962439	total: 24.9s	remaining: 24.4s
# 505:	learn: 0.3962388	total: 25s	remaining: 24.4s
# 506:	learn: 0.3962338	total: 25s	remaining: 24.3s
# 507:	learn: 0.3962312	total: 25.1s	remaining: 24.3s
# 508:	learn: 0.3962260	total: 25.1s	remaining: 24.2s
# 509:	learn: 0.3962192	total: 25.2s	remaining: 24.2s
# 510:	learn: 0.3962089	total: 25.2s	remaining: 24.1s
# 511:	learn: 0.3962016	total: 25.3s	remaining: 24.1s
# 512:	learn: 0.3961937	total: 25.3s	remaining: 24s
# 513:	learn: 0.3961812	total: 25.4s	remaining: 24s
# 514:	learn: 0.3961731	total: 25.4s	remaining: 23.9s
# 515:	learn: 0.3961669	total: 25.5s	remaining: 23.9s
# 516:	learn: 0.3961598	total: 25.5s	remaining: 23.8s
# 517:	learn: 0.3961537	total: 25.6s	remaining: 23.8s
# 518:	learn: 0.3961448	total: 25.6s	remaining: 23.7s
# 519:	learn: 0.3961402	total: 25.7s	remaining: 23.7s
# 520:	learn: 0.3961307	total: 25.7s	remaining: 23.6s
# 521:	learn: 0.3961235	total: 25.8s	remaining: 23.6s
# 522:	learn: 0.3961160	total: 25.8s	remaining: 23.5s
# 523:	learn: 0.3961073	total: 25.9s	remaining: 23.5s
# 524:	learn: 0.3961033	total: 25.9s	remaining: 23.4s
# 525:	learn: 0.3960991	total: 26s	remaining: 23.4s
# 526:	learn: 0.3960943	total: 26s	remaining: 23.3s
# 527:	learn: 0.3960918	total: 26.1s	remaining: 23.3s
# 528:	learn: 0.3960858	total: 26.1s	remaining: 23.2s
# 529:	learn: 0.3960778	total: 26.2s	remaining: 23.2s
# 530:	learn: 0.3960679	total: 26.2s	remaining: 23.1s
# 531:	learn: 0.3960564	total: 26.3s	remaining: 23.1s
# 532:	learn: 0.3960473	total: 26.3s	remaining: 23s
# 533:	learn: 0.3960386	total: 26.3s	remaining: 23s
# 534:	learn: 0.3960151	total: 26.4s	remaining: 22.9s
# 535:	learn: 0.3960104	total: 26.4s	remaining: 22.9s
# 536:	learn: 0.3960029	total: 26.5s	remaining: 22.8s
# 537:	learn: 0.3959954	total: 26.5s	remaining: 22.8s
# 538:	learn: 0.3959863	total: 26.6s	remaining: 22.7s
# 539:	learn: 0.3959795	total: 26.6s	remaining: 22.7s
# 540:	learn: 0.3959718	total: 26.7s	remaining: 22.6s
# 541:	learn: 0.3959641	total: 26.7s	remaining: 22.6s
# 542:	learn: 0.3959578	total: 26.8s	remaining: 22.5s
# 543:	learn: 0.3959542	total: 26.8s	remaining: 22.5s
# 544:	learn: 0.3959499	total: 26.9s	remaining: 22.4s
# 545:	learn: 0.3959447	total: 26.9s	remaining: 22.4s
# 546:	learn: 0.3959357	total: 27s	remaining: 22.3s
# 547:	learn: 0.3959300	total: 27s	remaining: 22.3s
# 548:	learn: 0.3959242	total: 27.1s	remaining: 22.3s
# 549:	learn: 0.3959198	total: 27.1s	remaining: 22.2s
# 550:	learn: 0.3959146	total: 27.2s	remaining: 22.2s
# 551:	learn: 0.3959058	total: 27.2s	remaining: 22.1s
# 552:	learn: 0.3959012	total: 27.3s	remaining: 22.1s
# 553:	learn: 0.3958978	total: 27.3s	remaining: 22s
# 554:	learn: 0.3958907	total: 27.4s	remaining: 22s
# 555:	learn: 0.3958823	total: 27.4s	remaining: 21.9s
# 556:	learn: 0.3958792	total: 27.5s	remaining: 21.9s
# 557:	learn: 0.3958714	total: 27.5s	remaining: 21.8s
# 558:	learn: 0.3958682	total: 27.6s	remaining: 21.8s
# 559:	learn: 0.3958626	total: 27.6s	remaining: 21.7s
# 560:	learn: 0.3958575	total: 27.7s	remaining: 21.7s
# 561:	learn: 0.3958530	total: 27.7s	remaining: 21.6s
# 562:	learn: 0.3958472	total: 27.8s	remaining: 21.6s
# 563:	learn: 0.3958395	total: 27.8s	remaining: 21.5s
# 564:	learn: 0.3958327	total: 27.9s	remaining: 21.5s
# 565:	learn: 0.3958279	total: 27.9s	remaining: 21.4s
# 566:	learn: 0.3958242	total: 28s	remaining: 21.4s
# 567:	learn: 0.3958101	total: 28s	remaining: 21.3s
# 568:	learn: 0.3958041	total: 28.1s	remaining: 21.3s
# 569:	learn: 0.3957975	total: 28.1s	remaining: 21.2s
# 570:	learn: 0.3957921	total: 28.2s	remaining: 21.2s
# 571:	learn: 0.3957806	total: 28.2s	remaining: 21.1s
# 572:	learn: 0.3957740	total: 28.3s	remaining: 21.1s
# 573:	learn: 0.3957700	total: 28.3s	remaining: 21s
# 574:	learn: 0.3957606	total: 28.4s	remaining: 21s
# 575:	learn: 0.3957464	total: 28.4s	remaining: 20.9s
# 576:	learn: 0.3957375	total: 28.5s	remaining: 20.9s
# 577:	learn: 0.3957309	total: 28.5s	remaining: 20.8s
# 578:	learn: 0.3957266	total: 28.6s	remaining: 20.8s
# 579:	learn: 0.3957174	total: 28.6s	remaining: 20.7s
# 580:	learn: 0.3957110	total: 28.7s	remaining: 20.7s
# 581:	learn: 0.3957078	total: 28.7s	remaining: 20.6s
# 582:	learn: 0.3957011	total: 28.8s	remaining: 20.6s
# 583:	learn: 0.3956915	total: 28.8s	remaining: 20.5s
# 584:	learn: 0.3956848	total: 28.9s	remaining: 20.5s
# 585:	learn: 0.3956791	total: 28.9s	remaining: 20.4s
# 586:	learn: 0.3956772	total: 29s	remaining: 20.4s
# 587:	learn: 0.3956730	total: 29s	remaining: 20.3s
# 588:	learn: 0.3956652	total: 29.1s	remaining: 20.3s
# 589:	learn: 0.3956615	total: 29.1s	remaining: 20.2s
# 590:	learn: 0.3956552	total: 29.2s	remaining: 20.2s
# 591:	learn: 0.3956519	total: 29.2s	remaining: 20.1s
# 592:	learn: 0.3956475	total: 29.3s	remaining: 20.1s
# 593:	learn: 0.3956457	total: 29.3s	remaining: 20s
# 594:	learn: 0.3956382	total: 29.4s	remaining: 20s
# 595:	learn: 0.3956339	total: 29.4s	remaining: 19.9s
# 596:	learn: 0.3956320	total: 29.4s	remaining: 19.9s
# 597:	learn: 0.3956248	total: 29.5s	remaining: 19.8s
# 598:	learn: 0.3956216	total: 29.6s	remaining: 19.8s
# 599:	learn: 0.3956154	total: 29.6s	remaining: 19.7s
# 600:	learn: 0.3956127	total: 29.7s	remaining: 19.7s
# 601:	learn: 0.3956092	total: 29.7s	remaining: 19.6s
# 602:	learn: 0.3956034	total: 29.8s	remaining: 19.6s
# 603:	learn: 0.3955991	total: 29.8s	remaining: 19.5s
# 604:	learn: 0.3955941	total: 29.9s	remaining: 19.5s
# 605:	learn: 0.3955890	total: 29.9s	remaining: 19.4s
# 606:	learn: 0.3955850	total: 30s	remaining: 19.4s
# 607:	learn: 0.3955799	total: 30s	remaining: 19.3s
# 608:	learn: 0.3955750	total: 30.1s	remaining: 19.3s
# 609:	learn: 0.3955713	total: 30.1s	remaining: 19.2s
# 610:	learn: 0.3955651	total: 30.1s	remaining: 19.2s
# 611:	learn: 0.3955592	total: 30.2s	remaining: 19.1s
# 612:	learn: 0.3955531	total: 30.2s	remaining: 19.1s
# 613:	learn: 0.3955496	total: 30.3s	remaining: 19s
# 614:	learn: 0.3955381	total: 30.3s	remaining: 19s
# 615:	learn: 0.3955331	total: 30.4s	remaining: 18.9s
# 616:	learn: 0.3955284	total: 30.4s	remaining: 18.9s
# 617:	learn: 0.3955219	total: 30.5s	remaining: 18.8s
# 618:	learn: 0.3955157	total: 30.5s	remaining: 18.8s
# 619:	learn: 0.3955114	total: 30.6s	remaining: 18.7s
# 620:	learn: 0.3955065	total: 30.6s	remaining: 18.7s
# 621:	learn: 0.3955000	total: 30.7s	remaining: 18.6s
# 622:	learn: 0.3954948	total: 30.7s	remaining: 18.6s
# 623:	learn: 0.3954882	total: 30.8s	remaining: 18.5s
# 624:	learn: 0.3954836	total: 30.8s	remaining: 18.5s
# 625:	learn: 0.3954807	total: 30.9s	remaining: 18.4s
# 626:	learn: 0.3954762	total: 30.9s	remaining: 18.4s
# 627:	learn: 0.3954727	total: 31s	remaining: 18.3s
# 628:	learn: 0.3954640	total: 31s	remaining: 18.3s
# 629:	learn: 0.3954608	total: 31.1s	remaining: 18.2s
# 630:	learn: 0.3954545	total: 31.1s	remaining: 18.2s
# 631:	learn: 0.3954514	total: 31.2s	remaining: 18.1s
# 632:	learn: 0.3954457	total: 31.2s	remaining: 18.1s
# 633:	learn: 0.3954403	total: 31.3s	remaining: 18s
# 634:	learn: 0.3954249	total: 31.3s	remaining: 18s
# 635:	learn: 0.3954190	total: 31.4s	remaining: 18s
# 636:	learn: 0.3954132	total: 31.4s	remaining: 17.9s
# 637:	learn: 0.3954106	total: 31.5s	remaining: 17.9s
# 638:	learn: 0.3954053	total: 31.5s	remaining: 17.8s
# 639:	learn: 0.3954029	total: 31.6s	remaining: 17.8s
# 640:	learn: 0.3953984	total: 31.6s	remaining: 17.7s
# 641:	learn: 0.3953940	total: 31.7s	remaining: 17.7s
# 642:	learn: 0.3953864	total: 31.7s	remaining: 17.6s
# 643:	learn: 0.3953814	total: 31.8s	remaining: 17.6s
# 644:	learn: 0.3953776	total: 31.8s	remaining: 17.5s
# 645:	learn: 0.3953727	total: 31.9s	remaining: 17.5s
# 646:	learn: 0.3953684	total: 31.9s	remaining: 17.4s
# 647:	learn: 0.3953658	total: 32s	remaining: 17.4s
# 648:	learn: 0.3953605	total: 32s	remaining: 17.3s
# 649:	learn: 0.3953559	total: 32.1s	remaining: 17.3s
# 650:	learn: 0.3953532	total: 32.1s	remaining: 17.2s
# 651:	learn: 0.3953497	total: 32.2s	remaining: 17.2s
# 652:	learn: 0.3953468	total: 32.2s	remaining: 17.1s
# 653:	learn: 0.3953419	total: 32.2s	remaining: 17.1s
# 654:	learn: 0.3953347	total: 32.3s	remaining: 17s
# 655:	learn: 0.3953195	total: 32.3s	remaining: 17s
# 656:	learn: 0.3953142	total: 32.4s	remaining: 16.9s
# 657:	learn: 0.3952896	total: 32.4s	remaining: 16.9s
# 658:	learn: 0.3952857	total: 32.5s	remaining: 16.8s
# 659:	learn: 0.3952807	total: 32.5s	remaining: 16.8s
# 660:	learn: 0.3952760	total: 32.6s	remaining: 16.7s
# 661:	learn: 0.3952720	total: 32.6s	remaining: 16.7s
# 662:	learn: 0.3952668	total: 32.7s	remaining: 16.6s
# 663:	learn: 0.3952620	total: 32.7s	remaining: 16.6s
# 664:	learn: 0.3952334	total: 32.8s	remaining: 16.5s
# 665:	learn: 0.3952283	total: 32.8s	remaining: 16.5s
# 666:	learn: 0.3952209	total: 32.9s	remaining: 16.4s
# 667:	learn: 0.3952145	total: 32.9s	remaining: 16.4s
# 668:	learn: 0.3952093	total: 33s	remaining: 16.3s
# 669:	learn: 0.3952027	total: 33s	remaining: 16.3s
# 670:	learn: 0.3951995	total: 33.1s	remaining: 16.2s
# 671:	learn: 0.3951962	total: 33.1s	remaining: 16.2s
# 672:	learn: 0.3951894	total: 33.2s	remaining: 16.1s
# 673:	learn: 0.3951841	total: 33.2s	remaining: 16.1s
# 674:	learn: 0.3951775	total: 33.3s	remaining: 16s
# 675:	learn: 0.3951711	total: 33.3s	remaining: 16s
# 676:	learn: 0.3951665	total: 33.4s	remaining: 15.9s
# 677:	learn: 0.3951598	total: 33.4s	remaining: 15.9s
# 678:	learn: 0.3951559	total: 33.5s	remaining: 15.8s
# 679:	learn: 0.3951483	total: 33.5s	remaining: 15.8s
# 680:	learn: 0.3951449	total: 33.6s	remaining: 15.7s
# 681:	learn: 0.3951414	total: 33.6s	remaining: 15.7s
# 682:	learn: 0.3951371	total: 33.7s	remaining: 15.6s
# 683:	learn: 0.3951301	total: 33.7s	remaining: 15.6s
# 684:	learn: 0.3951113	total: 33.8s	remaining: 15.5s
# 685:	learn: 0.3951075	total: 33.8s	remaining: 15.5s
# 686:	learn: 0.3951018	total: 33.9s	remaining: 15.4s
# 687:	learn: 0.3950976	total: 33.9s	remaining: 15.4s
# 688:	learn: 0.3950943	total: 34s	remaining: 15.3s
# 689:	learn: 0.3950884	total: 34s	remaining: 15.3s
# 690:	learn: 0.3950803	total: 34.1s	remaining: 15.2s
# 691:	learn: 0.3950786	total: 34.1s	remaining: 15.2s
# 692:	learn: 0.3950741	total: 34.2s	remaining: 15.1s
# 693:	learn: 0.3950690	total: 34.2s	remaining: 15.1s
# 694:	learn: 0.3950624	total: 34.3s	remaining: 15s
# 695:	learn: 0.3950582	total: 34.3s	remaining: 15s
# 696:	learn: 0.3950520	total: 34.3s	remaining: 14.9s
# 697:	learn: 0.3950472	total: 34.4s	remaining: 14.9s
# 698:	learn: 0.3950428	total: 34.5s	remaining: 14.8s
# 699:	learn: 0.3950402	total: 34.5s	remaining: 14.8s
# 700:	learn: 0.3950368	total: 34.6s	remaining: 14.7s
# 701:	learn: 0.3950342	total: 34.6s	remaining: 14.7s
# 702:	learn: 0.3950318	total: 34.6s	remaining: 14.6s
# 703:	learn: 0.3950259	total: 34.7s	remaining: 14.6s
# 704:	learn: 0.3950230	total: 34.7s	remaining: 14.5s
# 705:	learn: 0.3950178	total: 34.8s	remaining: 14.5s
# 706:	learn: 0.3950135	total: 34.8s	remaining: 14.4s
# 707:	learn: 0.3950095	total: 34.9s	remaining: 14.4s
# 708:	learn: 0.3949998	total: 34.9s	remaining: 14.3s
# 709:	learn: 0.3949951	total: 35s	remaining: 14.3s
# 710:	learn: 0.3949922	total: 35s	remaining: 14.2s
# 711:	learn: 0.3949877	total: 35.1s	remaining: 14.2s
# 712:	learn: 0.3949841	total: 35.1s	remaining: 14.1s
# 713:	learn: 0.3949799	total: 35.2s	remaining: 14.1s
# 714:	learn: 0.3949766	total: 35.2s	remaining: 14s
# 715:	learn: 0.3949722	total: 35.3s	remaining: 14s
# 716:	learn: 0.3949663	total: 35.3s	remaining: 13.9s
# 717:	learn: 0.3949626	total: 35.4s	remaining: 13.9s
# 718:	learn: 0.3949576	total: 35.4s	remaining: 13.8s
# 719:	learn: 0.3949508	total: 35.5s	remaining: 13.8s
# 720:	learn: 0.3949482	total: 35.5s	remaining: 13.8s
# 721:	learn: 0.3949432	total: 35.6s	remaining: 13.7s
# 722:	learn: 0.3949388	total: 35.6s	remaining: 13.7s
# 723:	learn: 0.3949330	total: 35.7s	remaining: 13.6s
# 724:	learn: 0.3949251	total: 35.7s	remaining: 13.6s
# 725:	learn: 0.3949193	total: 35.8s	remaining: 13.5s
# 726:	learn: 0.3949148	total: 35.8s	remaining: 13.5s
# 727:	learn: 0.3949102	total: 35.9s	remaining: 13.4s
# 728:	learn: 0.3949067	total: 35.9s	remaining: 13.4s
# 729:	learn: 0.3949012	total: 36s	remaining: 13.3s
# 730:	learn: 0.3948957	total: 36s	remaining: 13.3s
# 731:	learn: 0.3948906	total: 36.1s	remaining: 13.2s
# 732:	learn: 0.3948868	total: 36.1s	remaining: 13.2s
# 733:	learn: 0.3948808	total: 36.2s	remaining: 13.1s
# 734:	learn: 0.3948764	total: 36.2s	remaining: 13.1s
# 735:	learn: 0.3948745	total: 36.3s	remaining: 13s
# 736:	learn: 0.3948712	total: 36.3s	remaining: 13s
# 737:	learn: 0.3948663	total: 36.4s	remaining: 12.9s
# 738:	learn: 0.3948636	total: 36.4s	remaining: 12.9s
# 739:	learn: 0.3948603	total: 36.5s	remaining: 12.8s
# 740:	learn: 0.3948566	total: 36.5s	remaining: 12.8s
# 741:	learn: 0.3948536	total: 36.6s	remaining: 12.7s
# 742:	learn: 0.3948503	total: 36.6s	remaining: 12.7s
# 743:	learn: 0.3948483	total: 36.7s	remaining: 12.6s
# 744:	learn: 0.3948435	total: 36.7s	remaining: 12.6s
# 745:	learn: 0.3948394	total: 36.8s	remaining: 12.5s
# 746:	learn: 0.3948347	total: 36.8s	remaining: 12.5s
# 747:	learn: 0.3948316	total: 36.9s	remaining: 12.4s
# 748:	learn: 0.3948264	total: 36.9s	remaining: 12.4s
# 749:	learn: 0.3948241	total: 36.9s	remaining: 12.3s
# 750:	learn: 0.3948207	total: 37s	remaining: 12.3s
# 751:	learn: 0.3948176	total: 37s	remaining: 12.2s
# 752:	learn: 0.3948131	total: 37.1s	remaining: 12.2s
# 753:	learn: 0.3948096	total: 37.1s	remaining: 12.1s
# 754:	learn: 0.3948061	total: 37.2s	remaining: 12.1s
# 755:	learn: 0.3948035	total: 37.2s	remaining: 12s
# 756:	learn: 0.3948005	total: 37.3s	remaining: 12s
# 757:	learn: 0.3947952	total: 37.3s	remaining: 11.9s
# 758:	learn: 0.3947921	total: 37.4s	remaining: 11.9s
# 759:	learn: 0.3947876	total: 37.4s	remaining: 11.8s
# 760:	learn: 0.3947776	total: 37.5s	remaining: 11.8s
# 761:	learn: 0.3947727	total: 37.5s	remaining: 11.7s
# 762:	learn: 0.3947703	total: 37.6s	remaining: 11.7s
# 763:	learn: 0.3947670	total: 37.6s	remaining: 11.6s
# 764:	learn: 0.3947636	total: 37.7s	remaining: 11.6s
# 765:	learn: 0.3947593	total: 37.7s	remaining: 11.5s
# 766:	learn: 0.3947563	total: 37.8s	remaining: 11.5s
# 767:	learn: 0.3947505	total: 37.8s	remaining: 11.4s
# 768:	learn: 0.3947449	total: 37.9s	remaining: 11.4s
# 769:	learn: 0.3947270	total: 37.9s	remaining: 11.3s
# 770:	learn: 0.3947230	total: 38s	remaining: 11.3s
# 771:	learn: 0.3947190	total: 38s	remaining: 11.2s
# 772:	learn: 0.3947139	total: 38.1s	remaining: 11.2s
# 773:	learn: 0.3947104	total: 38.1s	remaining: 11.1s
# 774:	learn: 0.3947060	total: 38.2s	remaining: 11.1s
# 775:	learn: 0.3947015	total: 38.2s	remaining: 11s
# 776:	learn: 0.3946985	total: 38.3s	remaining: 11s
# 777:	learn: 0.3946955	total: 38.3s	remaining: 10.9s
# 778:	learn: 0.3946891	total: 38.4s	remaining: 10.9s
# 779:	learn: 0.3946837	total: 38.4s	remaining: 10.8s
# 780:	learn: 0.3946797	total: 38.5s	remaining: 10.8s
# 781:	learn: 0.3946761	total: 38.5s	remaining: 10.7s
# 782:	learn: 0.3946735	total: 38.6s	remaining: 10.7s
# 783:	learn: 0.3946689	total: 38.6s	remaining: 10.6s
# 784:	learn: 0.3946652	total: 38.7s	remaining: 10.6s
# 785:	learn: 0.3946618	total: 38.7s	remaining: 10.5s
# 786:	learn: 0.3946585	total: 38.8s	remaining: 10.5s
# 787:	learn: 0.3946537	total: 38.8s	remaining: 10.4s
# 788:	learn: 0.3946501	total: 38.9s	remaining: 10.4s
# 789:	learn: 0.3946460	total: 38.9s	remaining: 10.3s
# 790:	learn: 0.3946410	total: 39s	remaining: 10.3s
# 791:	learn: 0.3946390	total: 39s	remaining: 10.2s
# 792:	learn: 0.3946367	total: 39.1s	remaining: 10.2s
# 793:	learn: 0.3946328	total: 39.1s	remaining: 10.1s
# 794:	learn: 0.3946293	total: 39.2s	remaining: 10.1s
# 795:	learn: 0.3946267	total: 39.2s	remaining: 10s
# 796:	learn: 0.3946246	total: 39.3s	remaining: 10s
# 797:	learn: 0.3946208	total: 39.3s	remaining: 9.95s
# 798:	learn: 0.3946181	total: 39.4s	remaining: 9.9s
# 799:	learn: 0.3946138	total: 39.4s	remaining: 9.85s
# 800:	learn: 0.3946098	total: 39.5s	remaining: 9.8s
# 801:	learn: 0.3946056	total: 39.5s	remaining: 9.75s
# 802:	learn: 0.3945948	total: 39.6s	remaining: 9.7s
# 803:	learn: 0.3945927	total: 39.6s	remaining: 9.66s
# 804:	learn: 0.3945895	total: 39.7s	remaining: 9.61s
# 805:	learn: 0.3945855	total: 39.7s	remaining: 9.56s
# 806:	learn: 0.3945815	total: 39.8s	remaining: 9.51s
# 807:	learn: 0.3945765	total: 39.8s	remaining: 9.46s
# 808:	learn: 0.3945707	total: 39.9s	remaining: 9.41s
# 809:	learn: 0.3945655	total: 39.9s	remaining: 9.36s
# 810:	learn: 0.3945615	total: 40s	remaining: 9.31s
# 811:	learn: 0.3945586	total: 40s	remaining: 9.26s
# 812:	learn: 0.3945565	total: 40.1s	remaining: 9.21s
# 813:	learn: 0.3945530	total: 40.1s	remaining: 9.16s
# 814:	learn: 0.3945501	total: 40.2s	remaining: 9.12s
# 815:	learn: 0.3945463	total: 40.2s	remaining: 9.07s
# 816:	learn: 0.3945441	total: 40.3s	remaining: 9.02s
# 817:	learn: 0.3945420	total: 40.3s	remaining: 8.97s
# 818:	learn: 0.3945370	total: 40.4s	remaining: 8.92s
# 819:	learn: 0.3945335	total: 40.4s	remaining: 8.87s
# 820:	learn: 0.3945302	total: 40.5s	remaining: 8.82s
# 821:	learn: 0.3945240	total: 40.5s	remaining: 8.77s
# 822:	learn: 0.3945189	total: 40.6s	remaining: 8.72s
# 823:	learn: 0.3945138	total: 40.6s	remaining: 8.67s
# 824:	learn: 0.3945094	total: 40.6s	remaining: 8.62s
# 825:	learn: 0.3945063	total: 40.7s	remaining: 8.57s
# 826:	learn: 0.3945027	total: 40.7s	remaining: 8.52s
# 827:	learn: 0.3945000	total: 40.8s	remaining: 8.47s
# 828:	learn: 0.3944950	total: 40.8s	remaining: 8.43s
# 829:	learn: 0.3944938	total: 40.9s	remaining: 8.38s
# 830:	learn: 0.3944903	total: 40.9s	remaining: 8.33s
# 831:	learn: 0.3944870	total: 41s	remaining: 8.28s
# 832:	learn: 0.3944836	total: 41s	remaining: 8.23s
# 833:	learn: 0.3944810	total: 41.1s	remaining: 8.18s
# 834:	learn: 0.3944771	total: 41.1s	remaining: 8.13s
# 835:	learn: 0.3944724	total: 41.2s	remaining: 8.08s
# 836:	learn: 0.3944706	total: 41.2s	remaining: 8.03s
# 837:	learn: 0.3944678	total: 41.3s	remaining: 7.98s
# 838:	learn: 0.3944638	total: 41.3s	remaining: 7.93s
# 839:	learn: 0.3944605	total: 41.4s	remaining: 7.88s
# 840:	learn: 0.3944526	total: 41.4s	remaining: 7.83s
# 841:	learn: 0.3944490	total: 41.5s	remaining: 7.78s
# 842:	learn: 0.3944460	total: 41.5s	remaining: 7.73s
# 843:	learn: 0.3944431	total: 41.6s	remaining: 7.68s
# 844:	learn: 0.3944398	total: 41.6s	remaining: 7.63s
# 845:	learn: 0.3944333	total: 41.7s	remaining: 7.59s
# 846:	learn: 0.3944299	total: 41.7s	remaining: 7.54s
# 847:	learn: 0.3944257	total: 41.8s	remaining: 7.49s
# 848:	learn: 0.3944219	total: 41.8s	remaining: 7.44s
# 849:	learn: 0.3944182	total: 41.9s	remaining: 7.39s
# 850:	learn: 0.3944090	total: 41.9s	remaining: 7.34s
# 851:	learn: 0.3944032	total: 42s	remaining: 7.29s
# 852:	learn: 0.3944000	total: 42s	remaining: 7.24s
# 853:	learn: 0.3943970	total: 42.1s	remaining: 7.19s
# 854:	learn: 0.3943939	total: 42.1s	remaining: 7.14s
# 855:	learn: 0.3943912	total: 42.2s	remaining: 7.09s
# 856:	learn: 0.3943681	total: 42.2s	remaining: 7.04s
# 857:	learn: 0.3943648	total: 42.3s	remaining: 6.99s
# 858:	learn: 0.3943594	total: 42.3s	remaining: 6.94s
# 859:	learn: 0.3943568	total: 42.4s	remaining: 6.89s
# 860:	learn: 0.3943534	total: 42.4s	remaining: 6.84s
# 861:	learn: 0.3943510	total: 42.5s	remaining: 6.8s
# 862:	learn: 0.3943480	total: 42.5s	remaining: 6.75s
# 863:	learn: 0.3943441	total: 42.6s	remaining: 6.7s
# 864:	learn: 0.3943405	total: 42.6s	remaining: 6.65s
# 865:	learn: 0.3943381	total: 42.7s	remaining: 6.6s
# 866:	learn: 0.3943348	total: 42.7s	remaining: 6.55s
# 867:	learn: 0.3943313	total: 42.8s	remaining: 6.5s
# 868:	learn: 0.3943238	total: 42.8s	remaining: 6.45s
# 869:	learn: 0.3943199	total: 42.9s	remaining: 6.4s
# 870:	learn: 0.3943165	total: 42.9s	remaining: 6.35s
# 871:	learn: 0.3943144	total: 43s	remaining: 6.3s
# 872:	learn: 0.3943119	total: 43s	remaining: 6.25s
# 873:	learn: 0.3943070	total: 43s	remaining: 6.21s
# 874:	learn: 0.3943032	total: 43.1s	remaining: 6.16s
# 875:	learn: 0.3942992	total: 43.1s	remaining: 6.11s
# 876:	learn: 0.3942957	total: 43.2s	remaining: 6.06s
# 877:	learn: 0.3942931	total: 43.2s	remaining: 6.01s
# 878:	learn: 0.3942912	total: 43.3s	remaining: 5.96s
# 879:	learn: 0.3942869	total: 43.3s	remaining: 5.91s
# 880:	learn: 0.3942839	total: 43.4s	remaining: 5.86s
# 881:	learn: 0.3942828	total: 43.4s	remaining: 5.81s
# 882:	learn: 0.3942803	total: 43.5s	remaining: 5.76s
# 883:	learn: 0.3942771	total: 43.5s	remaining: 5.71s
# 884:	learn: 0.3942703	total: 43.6s	remaining: 5.66s
# 885:	learn: 0.3942670	total: 43.6s	remaining: 5.61s
# 886:	learn: 0.3942647	total: 43.7s	remaining: 5.56s
# 887:	learn: 0.3942602	total: 43.7s	remaining: 5.51s
# 888:	learn: 0.3942573	total: 43.8s	remaining: 5.47s
# 889:	learn: 0.3942532	total: 43.8s	remaining: 5.42s
# 890:	learn: 0.3942490	total: 43.9s	remaining: 5.37s
# 891:	learn: 0.3942455	total: 43.9s	remaining: 5.32s
# 892:	learn: 0.3942434	total: 44s	remaining: 5.27s
# 893:	learn: 0.3942396	total: 44s	remaining: 5.22s
# 894:	learn: 0.3942356	total: 44.1s	remaining: 5.17s
# 895:	learn: 0.3942326	total: 44.1s	remaining: 5.12s
# 896:	learn: 0.3942292	total: 44.2s	remaining: 5.07s
# 897:	learn: 0.3942249	total: 44.2s	remaining: 5.02s
# 898:	learn: 0.3942205	total: 44.3s	remaining: 4.97s
# 899:	learn: 0.3942168	total: 44.3s	remaining: 4.92s
# 900:	learn: 0.3942134	total: 44.4s	remaining: 4.88s
# 901:	learn: 0.3942107	total: 44.4s	remaining: 4.83s
# 902:	learn: 0.3942086	total: 44.5s	remaining: 4.78s
# 903:	learn: 0.3942049	total: 44.5s	remaining: 4.73s
# 904:	learn: 0.3942024	total: 44.6s	remaining: 4.68s
# 905:	learn: 0.3941984	total: 44.6s	remaining: 4.63s
# 906:	learn: 0.3941967	total: 44.7s	remaining: 4.58s
# 907:	learn: 0.3941934	total: 44.7s	remaining: 4.53s
# 908:	learn: 0.3941899	total: 44.8s	remaining: 4.48s
# 909:	learn: 0.3941777	total: 44.8s	remaining: 4.43s
# 910:	learn: 0.3941714	total: 44.9s	remaining: 4.38s
# 911:	learn: 0.3941649	total: 44.9s	remaining: 4.33s
# 912:	learn: 0.3941619	total: 45s	remaining: 4.28s
# 913:	learn: 0.3941585	total: 45s	remaining: 4.24s
# 914:	learn: 0.3941560	total: 45.1s	remaining: 4.19s
# 915:	learn: 0.3941532	total: 45.1s	remaining: 4.14s
# 916:	learn: 0.3941514	total: 45.2s	remaining: 4.09s
# 917:	learn: 0.3941486	total: 45.2s	remaining: 4.04s
# 918:	learn: 0.3941447	total: 45.3s	remaining: 3.99s
# 919:	learn: 0.3941410	total: 45.3s	remaining: 3.94s
# 920:	learn: 0.3941381	total: 45.4s	remaining: 3.89s
# 921:	learn: 0.3941356	total: 45.4s	remaining: 3.84s
# 922:	learn: 0.3941326	total: 45.5s	remaining: 3.79s
# 923:	learn: 0.3941187	total: 45.5s	remaining: 3.74s
# 924:	learn: 0.3941157	total: 45.6s	remaining: 3.69s
# ...
# 692:	learn: 0.1868582	total: 23.7s	remaining: 10.5s
# 693:	learn: 0.1868391	total: 23.7s	remaining: 10.5s
# 694:	learn: 0.1868315	total: 23.8s	remaining: 10.4s
# 695:	learn: 0.1868235	total: 23.8s	remaining: 10.4s
# 696:	learn: 0.1868154	total: 23.8s	remaining: 10.4s
# 697:	learn: 0.1868063	total: 23.9s	remaining: 10.3s
# 698:	learn: 0.1867921	total: 23.9s	remaining: 10.3s
# 699:	learn: 0.1867804	total: 23.9s	remaining: 10.3s
# 700:	learn: 0.1867710	total: 24s	remaining: 10.2s
# 701:	learn: 0.1867632	total: 24s	remaining: 10.2s
# 702:	learn: 0.1867547	total: 24s	remaining: 10.2s
# 703:	learn: 0.1867350	total: 24.1s	remaining: 10.1s
# 704:	learn: 0.1867247	total: 24.1s	remaining: 10.1s
# 705:	learn: 0.1867103	total: 24.1s	remaining: 10.1s
# 706:	learn: 0.1866975	total: 24.2s	remaining: 10s
# 707:	learn: 0.1866908	total: 24.2s	remaining: 9.98s
# 708:	learn: 0.1866830	total: 24.2s	remaining: 9.95s
# 709:	learn: 0.1866719	total: 24.3s	remaining: 9.92s
# 710:	learn: 0.1866628	total: 24.3s	remaining: 9.88s
# 711:	learn: 0.1866544	total: 24.3s	remaining: 9.85s
# 712:	learn: 0.1866463	total: 24.4s	remaining: 9.81s
# 713:	learn: 0.1866390	total: 24.4s	remaining: 9.78s
# 714:	learn: 0.1866229	total: 24.5s	remaining: 9.75s
# 715:	learn: 0.1866107	total: 24.5s	remaining: 9.71s
# 716:	learn: 0.1865969	total: 24.5s	remaining: 9.68s
# 717:	learn: 0.1865883	total: 24.6s	remaining: 9.64s
# 718:	learn: 0.1865835	total: 24.6s	remaining: 9.61s
# 719:	learn: 0.1865737	total: 24.6s	remaining: 9.58s
# 720:	learn: 0.1865638	total: 24.7s	remaining: 9.54s
# 721:	learn: 0.1865503	total: 24.7s	remaining: 9.51s
# 722:	learn: 0.1865413	total: 24.7s	remaining: 9.47s
# 723:	learn: 0.1865339	total: 24.8s	remaining: 9.44s
# 724:	learn: 0.1865290	total: 24.8s	remaining: 9.41s
# 725:	learn: 0.1865196	total: 24.8s	remaining: 9.37s
# 726:	learn: 0.1865105	total: 24.9s	remaining: 9.34s
# 727:	learn: 0.1865032	total: 24.9s	remaining: 9.3s
# 728:	learn: 0.1864950	total: 24.9s	remaining: 9.27s
# 729:	learn: 0.1864894	total: 25s	remaining: 9.24s
# 730:	learn: 0.1864834	total: 25s	remaining: 9.2s
# 731:	learn: 0.1864740	total: 25s	remaining: 9.17s
# 732:	learn: 0.1864691	total: 25.1s	remaining: 9.13s
# 733:	learn: 0.1864599	total: 25.1s	remaining: 9.1s
# 734:	learn: 0.1864504	total: 25.1s	remaining: 9.06s
# 735:	learn: 0.1864417	total: 25.2s	remaining: 9.03s
# 736:	learn: 0.1864354	total: 25.2s	remaining: 9s
# 737:	learn: 0.1864244	total: 25.2s	remaining: 8.96s
# 738:	learn: 0.1864143	total: 25.3s	remaining: 8.93s
# 739:	learn: 0.1864077	total: 25.3s	remaining: 8.89s
# 740:	learn: 0.1863998	total: 25.3s	remaining: 8.86s
# 741:	learn: 0.1863921	total: 25.4s	remaining: 8.82s
# 742:	learn: 0.1863831	total: 25.4s	remaining: 8.79s
# 743:	learn: 0.1863734	total: 25.4s	remaining: 8.76s
# 744:	learn: 0.1863613	total: 25.5s	remaining: 8.72s
# 745:	learn: 0.1863542	total: 25.5s	remaining: 8.69s
# 746:	learn: 0.1863475	total: 25.5s	remaining: 8.65s
# 747:	learn: 0.1863420	total: 25.6s	remaining: 8.62s
# 748:	learn: 0.1863321	total: 25.6s	remaining: 8.59s
# 749:	learn: 0.1863211	total: 25.7s	remaining: 8.55s
# 750:	learn: 0.1863104	total: 25.7s	remaining: 8.52s
# 751:	learn: 0.1863018	total: 25.7s	remaining: 8.48s
# 752:	learn: 0.1862931	total: 25.8s	remaining: 8.45s
# 753:	learn: 0.1862873	total: 25.8s	remaining: 8.42s
# 754:	learn: 0.1862811	total: 25.8s	remaining: 8.38s
# 755:	learn: 0.1862758	total: 25.9s	remaining: 8.35s
# 756:	learn: 0.1862651	total: 25.9s	remaining: 8.31s
# 757:	learn: 0.1862523	total: 25.9s	remaining: 8.28s
# 758:	learn: 0.1862440	total: 26s	remaining: 8.25s
# 759:	learn: 0.1862358	total: 26s	remaining: 8.21s
# 760:	learn: 0.1862294	total: 26s	remaining: 8.18s
# 761:	learn: 0.1862244	total: 26.1s	remaining: 8.14s
# 762:	learn: 0.1862169	total: 26.1s	remaining: 8.11s
# 763:	learn: 0.1862030	total: 26.1s	remaining: 8.07s
# 764:	learn: 0.1861914	total: 26.2s	remaining: 8.04s
# 765:	learn: 0.1861822	total: 26.2s	remaining: 8s
# 766:	learn: 0.1861729	total: 26.2s	remaining: 7.97s
# 767:	learn: 0.1861654	total: 26.3s	remaining: 7.93s
# 768:	learn: 0.1861573	total: 26.3s	remaining: 7.9s
# 769:	learn: 0.1861492	total: 26.3s	remaining: 7.87s
# 770:	learn: 0.1861440	total: 26.4s	remaining: 7.83s
# 771:	learn: 0.1861370	total: 26.4s	remaining: 7.8s
# 772:	learn: 0.1861270	total: 26.4s	remaining: 7.76s
# 773:	learn: 0.1861213	total: 26.5s	remaining: 7.73s
# 774:	learn: 0.1861119	total: 26.5s	remaining: 7.7s
# 775:	learn: 0.1861012	total: 26.5s	remaining: 7.66s
# 776:	learn: 0.1860895	total: 26.6s	remaining: 7.63s
# 777:	learn: 0.1860829	total: 26.6s	remaining: 7.59s
# 778:	learn: 0.1860699	total: 26.6s	remaining: 7.56s
# 779:	learn: 0.1860635	total: 26.7s	remaining: 7.53s
# 780:	learn: 0.1860548	total: 26.7s	remaining: 7.49s
# 781:	learn: 0.1860469	total: 26.8s	remaining: 7.46s
# 782:	learn: 0.1860353	total: 26.8s	remaining: 7.42s
# 783:	learn: 0.1860225	total: 26.8s	remaining: 7.39s
# 784:	learn: 0.1860151	total: 26.9s	remaining: 7.35s
# 785:	learn: 0.1860017	total: 26.9s	remaining: 7.32s
# 786:	learn: 0.1859942	total: 26.9s	remaining: 7.29s
# 787:	learn: 0.1859850	total: 27s	remaining: 7.25s
# 788:	learn: 0.1859774	total: 27s	remaining: 7.22s
# 789:	learn: 0.1859713	total: 27s	remaining: 7.18s
# 790:	learn: 0.1859615	total: 27.1s	remaining: 7.15s
# 791:	learn: 0.1859555	total: 27.1s	remaining: 7.12s
# 792:	learn: 0.1859485	total: 27.1s	remaining: 7.08s
# 793:	learn: 0.1859375	total: 27.2s	remaining: 7.05s
# 794:	learn: 0.1859184	total: 27.2s	remaining: 7.01s
# 795:	learn: 0.1859083	total: 27.2s	remaining: 6.98s
# 796:	learn: 0.1858993	total: 27.3s	remaining: 6.94s
# 797:	learn: 0.1858908	total: 27.3s	remaining: 6.91s
# 798:	learn: 0.1858825	total: 27.3s	remaining: 6.88s
# 799:	learn: 0.1858772	total: 27.4s	remaining: 6.84s
# 800:	learn: 0.1858529	total: 27.4s	remaining: 6.81s
# 801:	learn: 0.1858456	total: 27.4s	remaining: 6.77s
# 802:	learn: 0.1858366	total: 27.5s	remaining: 6.74s
# 803:	learn: 0.1858321	total: 27.5s	remaining: 6.71s
# 804:	learn: 0.1858288	total: 27.5s	remaining: 6.67s
# 805:	learn: 0.1858212	total: 27.6s	remaining: 6.64s
# 806:	learn: 0.1858145	total: 27.6s	remaining: 6.6s
# 807:	learn: 0.1858058	total: 27.7s	remaining: 6.57s
# 808:	learn: 0.1857964	total: 27.7s	remaining: 6.54s
# 809:	learn: 0.1857904	total: 27.7s	remaining: 6.5s
# 810:	learn: 0.1857815	total: 27.8s	remaining: 6.47s
# 811:	learn: 0.1857753	total: 27.8s	remaining: 6.43s
# 812:	learn: 0.1857657	total: 27.8s	remaining: 6.4s
# 813:	learn: 0.1857592	total: 27.9s	remaining: 6.37s
# 814:	learn: 0.1857534	total: 27.9s	remaining: 6.33s
# 815:	learn: 0.1857287	total: 27.9s	remaining: 6.3s
# 816:	learn: 0.1857204	total: 28s	remaining: 6.26s
# 817:	learn: 0.1857127	total: 28s	remaining: 6.23s
# 818:	learn: 0.1856958	total: 28s	remaining: 6.2s
# 819:	learn: 0.1856888	total: 28.1s	remaining: 6.16s
# 820:	learn: 0.1856813	total: 28.1s	remaining: 6.13s
# 821:	learn: 0.1856725	total: 28.1s	remaining: 6.09s
# 822:	learn: 0.1856638	total: 28.2s	remaining: 6.06s
# 823:	learn: 0.1856568	total: 28.2s	remaining: 6.03s
# 824:	learn: 0.1856507	total: 28.2s	remaining: 5.99s
# 825:	learn: 0.1856404	total: 28.3s	remaining: 5.96s
# 826:	learn: 0.1856343	total: 28.3s	remaining: 5.92s
# 827:	learn: 0.1856256	total: 28.4s	remaining: 5.89s
# 828:	learn: 0.1856203	total: 28.4s	remaining: 5.86s
# 829:	learn: 0.1856144	total: 28.4s	remaining: 5.82s
# 830:	learn: 0.1856082	total: 28.5s	remaining: 5.79s
# 831:	learn: 0.1855999	total: 28.5s	remaining: 5.75s
# 832:	learn: 0.1855942	total: 28.5s	remaining: 5.72s
# 833:	learn: 0.1855844	total: 28.6s	remaining: 5.68s
# 834:	learn: 0.1855773	total: 28.6s	remaining: 5.65s
# 835:	learn: 0.1855665	total: 28.6s	remaining: 5.62s
# 836:	learn: 0.1855600	total: 28.7s	remaining: 5.58s
# 837:	learn: 0.1855542	total: 28.7s	remaining: 5.55s
# 838:	learn: 0.1855470	total: 28.7s	remaining: 5.51s
# 839:	learn: 0.1855418	total: 28.8s	remaining: 5.48s
# 840:	learn: 0.1855303	total: 28.8s	remaining: 5.44s
# 841:	learn: 0.1855198	total: 28.8s	remaining: 5.41s
# 842:	learn: 0.1855100	total: 28.9s	remaining: 5.37s
# 843:	learn: 0.1855003	total: 28.9s	remaining: 5.34s
# 844:	learn: 0.1854902	total: 28.9s	remaining: 5.31s
# 845:	learn: 0.1854827	total: 29s	remaining: 5.27s
# 846:	learn: 0.1854741	total: 29s	remaining: 5.24s
# 847:	learn: 0.1854636	total: 29s	remaining: 5.2s
# 848:	learn: 0.1854580	total: 29.1s	remaining: 5.17s
# 849:	learn: 0.1854481	total: 29.1s	remaining: 5.13s
# 850:	learn: 0.1854392	total: 29.1s	remaining: 5.1s
# 851:	learn: 0.1854289	total: 29.2s	remaining: 5.06s
# 852:	learn: 0.1854194	total: 29.2s	remaining: 5.03s
# 853:	learn: 0.1854105	total: 29.2s	remaining: 5s
# 854:	learn: 0.1854025	total: 29.3s	remaining: 4.96s
# 855:	learn: 0.1853923	total: 29.3s	remaining: 4.93s
# 856:	learn: 0.1853843	total: 29.3s	remaining: 4.89s
# 857:	learn: 0.1853800	total: 29.4s	remaining: 4.86s
# 858:	learn: 0.1853696	total: 29.4s	remaining: 4.82s
# 859:	learn: 0.1853624	total: 29.4s	remaining: 4.79s
# 860:	learn: 0.1853516	total: 29.5s	remaining: 4.75s
# 861:	learn: 0.1853432	total: 29.5s	remaining: 4.72s
# 862:	learn: 0.1853361	total: 29.5s	remaining: 4.69s
# 863:	learn: 0.1853293	total: 29.6s	remaining: 4.65s
# 864:	learn: 0.1853254	total: 29.6s	remaining: 4.62s
# 865:	learn: 0.1853193	total: 29.6s	remaining: 4.58s
# 866:	learn: 0.1853092	total: 29.7s	remaining: 4.55s
# 867:	learn: 0.1853031	total: 29.7s	remaining: 4.52s
# 868:	learn: 0.1852971	total: 29.7s	remaining: 4.48s
# 869:	learn: 0.1852805	total: 29.8s	remaining: 4.45s
# 870:	learn: 0.1852721	total: 29.8s	remaining: 4.41s
# 871:	learn: 0.1852573	total: 29.8s	remaining: 4.38s
# 872:	learn: 0.1852492	total: 29.9s	remaining: 4.34s
# 873:	learn: 0.1852391	total: 29.9s	remaining: 4.31s
# 874:	learn: 0.1852214	total: 29.9s	remaining: 4.28s
# 875:	learn: 0.1852131	total: 30s	remaining: 4.24s
# 876:	learn: 0.1852040	total: 30s	remaining: 4.21s
# 877:	learn: 0.1851972	total: 30s	remaining: 4.17s
# 878:	learn: 0.1851857	total: 30.1s	remaining: 4.14s
# 879:	learn: 0.1851795	total: 30.1s	remaining: 4.11s
# 880:	learn: 0.1851743	total: 30.1s	remaining: 4.07s
# 881:	learn: 0.1851666	total: 30.2s	remaining: 4.04s
# 882:	learn: 0.1851610	total: 30.2s	remaining: 4s
# 883:	learn: 0.1851505	total: 30.2s	remaining: 3.97s
# 884:	learn: 0.1851439	total: 30.3s	remaining: 3.93s
# 885:	learn: 0.1851391	total: 30.3s	remaining: 3.9s
# 886:	learn: 0.1851306	total: 30.3s	remaining: 3.87s
# 887:	learn: 0.1851222	total: 30.4s	remaining: 3.83s
# 888:	learn: 0.1851146	total: 30.4s	remaining: 3.8s
# 889:	learn: 0.1851012	total: 30.4s	remaining: 3.76s
# 890:	learn: 0.1850917	total: 30.5s	remaining: 3.73s
# 891:	learn: 0.1850789	total: 30.5s	remaining: 3.69s
# 892:	learn: 0.1850737	total: 30.5s	remaining: 3.66s
# 893:	learn: 0.1850613	total: 30.6s	remaining: 3.63s
# 894:	learn: 0.1850499	total: 30.6s	remaining: 3.59s
# 895:	learn: 0.1850415	total: 30.6s	remaining: 3.56s
# 896:	learn: 0.1850334	total: 30.7s	remaining: 3.52s
# 897:	learn: 0.1850191	total: 30.7s	remaining: 3.49s
# 898:	learn: 0.1850070	total: 30.7s	remaining: 3.45s
# 899:	learn: 0.1849959	total: 30.8s	remaining: 3.42s
# 900:	learn: 0.1849858	total: 30.8s	remaining: 3.38s
# 901:	learn: 0.1849767	total: 30.8s	remaining: 3.35s
# 902:	learn: 0.1849715	total: 30.9s	remaining: 3.32s
# 903:	learn: 0.1849621	total: 30.9s	remaining: 3.28s
# 904:	learn: 0.1849531	total: 30.9s	remaining: 3.25s
# 905:	learn: 0.1849424	total: 31s	remaining: 3.21s
# 906:	learn: 0.1849350	total: 31s	remaining: 3.18s
# 907:	learn: 0.1849211	total: 31s	remaining: 3.15s
# 908:	learn: 0.1849107	total: 31.1s	remaining: 3.11s
# 909:	learn: 0.1849026	total: 31.1s	remaining: 3.08s
# 910:	learn: 0.1848961	total: 31.1s	remaining: 3.04s
# 911:	learn: 0.1848821	total: 31.2s	remaining: 3.01s
# 912:	learn: 0.1848729	total: 31.2s	remaining: 2.97s
# 913:	learn: 0.1848625	total: 31.2s	remaining: 2.94s
# 914:	learn: 0.1848567	total: 31.3s	remaining: 2.9s
# 915:	learn: 0.1848414	total: 31.3s	remaining: 2.87s
# 916:	learn: 0.1848324	total: 31.3s	remaining: 2.84s
# 917:	learn: 0.1848265	total: 31.4s	remaining: 2.8s
# 918:	learn: 0.1848210	total: 31.4s	remaining: 2.77s
# 919:	learn: 0.1848146	total: 31.4s	remaining: 2.73s
# 920:	learn: 0.1848060	total: 31.5s	remaining: 2.7s
# 921:	learn: 0.1848003	total: 31.5s	remaining: 2.67s
# 922:	learn: 0.1847934	total: 31.6s	remaining: 2.63s
# 923:	learn: 0.1847862	total: 31.6s	remaining: 2.6s
# 924:	learn: 0.1847780	total: 31.6s	remaining: 2.56s
# 925:	learn: 0.1847682	total: 31.7s	remaining: 2.53s
# 926:	learn: 0.1847611	total: 31.7s	remaining: 2.5s
# 927:	learn: 0.1847503	total: 31.7s	remaining: 2.46s
# 928:	learn: 0.1847441	total: 31.7s	remaining: 2.43s
# 929:	learn: 0.1847345	total: 31.8s	remaining: 2.39s
# 930:	learn: 0.1847278	total: 31.8s	remaining: 2.36s
# 931:	learn: 0.1847214	total: 31.9s	remaining: 2.32s
# 932:	learn: 0.1847133	total: 31.9s	remaining: 2.29s
# 933:	learn: 0.1847013	total: 31.9s	remaining: 2.25s
# 934:	learn: 0.1846923	total: 32s	remaining: 2.22s
# 935:	learn: 0.1846813	total: 32s	remaining: 2.19s
# 936:	learn: 0.1846748	total: 32s	remaining: 2.15s
# 937:	learn: 0.1846664	total: 32.1s	remaining: 2.12s
# 938:	learn: 0.1846604	total: 32.1s	remaining: 2.08s
# 939:	learn: 0.1846543	total: 32.1s	remaining: 2.05s
# 940:	learn: 0.1846473	total: 32.2s	remaining: 2.02s
# 941:	learn: 0.1846379	total: 32.2s	remaining: 1.98s
# 942:	learn: 0.1846275	total: 32.2s	remaining: 1.95s
# 943:	learn: 0.1846123	total: 32.3s	remaining: 1.91s
# 944:	learn: 0.1846031	total: 32.3s	remaining: 1.88s
# 945:	learn: 0.1845967	total: 32.3s	remaining: 1.84s
# 946:	learn: 0.1845865	total: 32.4s	remaining: 1.81s
# 947:	learn: 0.1845786	total: 32.4s	remaining: 1.78s
# 948:	learn: 0.1845705	total: 32.4s	remaining: 1.74s
# 949:	learn: 0.1845607	total: 32.5s	remaining: 1.71s
# 950:	learn: 0.1845536	total: 32.5s	remaining: 1.67s
# 951:	learn: 0.1845460	total: 32.5s	remaining: 1.64s
# 952:	learn: 0.1845371	total: 32.6s	remaining: 1.61s
# 953:	learn: 0.1845295	total: 32.6s	remaining: 1.57s
# 954:	learn: 0.1845239	total: 32.6s	remaining: 1.54s
# 955:	learn: 0.1845179	total: 32.7s	remaining: 1.5s
# 956:	learn: 0.1845102	total: 32.7s	remaining: 1.47s
# 957:	learn: 0.1845004	total: 32.7s	remaining: 1.44s
# 958:	learn: 0.1844900	total: 32.8s	remaining: 1.4s
# 959:	learn: 0.1844792	total: 32.8s	remaining: 1.37s
# 960:	learn: 0.1844721	total: 32.8s	remaining: 1.33s
# 961:	learn: 0.1844643	total: 32.9s	remaining: 1.3s
# 962:	learn: 0.1844599	total: 32.9s	remaining: 1.26s
# 963:	learn: 0.1844523	total: 32.9s	remaining: 1.23s
# 964:	learn: 0.1844440	total: 33s	remaining: 1.2s
# 965:	learn: 0.1844383	total: 33s	remaining: 1.16s
# 966:	learn: 0.1844323	total: 33.1s	remaining: 1.13s
# 967:	learn: 0.1844241	total: 33.1s	remaining: 1.09s
# 968:	learn: 0.1844047	total: 33.1s	remaining: 1.06s
# 969:	learn: 0.1844006	total: 33.2s	remaining: 1.02s
# 970:	learn: 0.1843950	total: 33.2s	remaining: 991ms
# 971:	learn: 0.1843810	total: 33.2s	remaining: 957ms
# 972:	learn: 0.1843732	total: 33.3s	remaining: 923ms
# 973:	learn: 0.1843664	total: 33.3s	remaining: 889ms
# 974:	learn: 0.1843615	total: 33.3s	remaining: 854ms
# 975:	learn: 0.1843561	total: 33.4s	remaining: 820ms
# 976:	learn: 0.1843501	total: 33.4s	remaining: 786ms
# 977:	learn: 0.1843439	total: 33.4s	remaining: 752ms
# 978:	learn: 0.1843416	total: 33.5s	remaining: 718ms
# 979:	learn: 0.1843331	total: 33.5s	remaining: 684ms
# 980:	learn: 0.1843236	total: 33.5s	remaining: 649ms
# 981:	learn: 0.1843144	total: 33.6s	remaining: 615ms
# 982:	learn: 0.1843085	total: 33.6s	remaining: 581ms
# 983:	learn: 0.1843042	total: 33.6s	remaining: 547ms
# 984:	learn: 0.1842955	total: 33.7s	remaining: 513ms
# 985:	learn: 0.1842861	total: 33.7s	remaining: 479ms
# 986:	learn: 0.1842795	total: 33.7s	remaining: 444ms
# 987:	learn: 0.1842712	total: 33.8s	remaining: 410ms
# 988:	learn: 0.1842609	total: 33.8s	remaining: 376ms
# 989:	learn: 0.1842540	total: 33.8s	remaining: 342ms
# 990:	learn: 0.1842428	total: 33.9s	remaining: 308ms
# 991:	learn: 0.1842379	total: 33.9s	remaining: 273ms
# 992:	learn: 0.1842253	total: 33.9s	remaining: 239ms
# 993:	learn: 0.1842155	total: 34s	remaining: 205ms
# 994:	learn: 0.1842083	total: 34s	remaining: 171ms
# 995:	learn: 0.1841998	total: 34s	remaining: 137ms
# 996:	learn: 0.1841926	total: 34.1s	remaining: 103ms
# 997:	learn: 0.1841833	total: 34.1s	remaining: 68.4ms
# 998:	learn: 0.1841776	total: 34.2s	remaining: 34.2ms
# 999:	learn: 0.1841727	total: 34.2s	remaining: 0us
# type: 100%|██████████| 3/3 [06:12<00:00, 124.17s/it]
# training_done

# %% [markdown]
# ## Предсказание + оценка

# %%
lv_predictions_full = pd.DataFrame()

for typee in tqdm(['clicks', 'carts', 'orders'], desc='type'):

    if os.path.exists(f'/content/test_candidates_{typee}') == False:
        # импорт кандидатов выбранного типа
        shutil.copytree(f'{main_path}/lv/ver_6/test_candidates_{typee}/',
                        f'/content/test_candidates_{typee}/')

    path = f'test_candidates_{typee}/*'
    test_candidates = read_parquets(path)
    test_candidates = test_candidates.sort_values('session')
    test_candidates = test_candidates.reset_index(drop=True)

    # Создание предсказаний
    FEATURES = test_candidates.columns[2:]
    dtest = Pool(data=test_candidates[FEATURES])
    preds = np.zeros(len(test_candidates))
    model = CatBoostRanker(random_state=42)
    model.load_model(f'model/baseline/{ver_folder}/catb_base_{typee}')
    preds = model.predict(dtest)

    # Получение топ-20 предсказаний для каждой сессии и доп преобразования
    lv_predictions = test_candidates[['session', 'aid']].copy()
    lv_predictions['pred'] = preds
    lv_predictions = lv_predictions.sort_values(
        ['session', 'pred'], ascending=[True, False]).reset_index(drop=True)
    lv_predictions['n'] = lv_predictions.groupby(
        'session').aid.cumcount().astype('int8')
    lv_predictions = lv_predictions.loc[lv_predictions.n < 20]
    lv_predictions = lv_predictions.groupby('session').aid.apply(list)
    lv_predictions = lv_predictions.to_frame().reset_index()
    lv_predictions.rename(columns={'aid': 'labels'}, inplace=True)
    lv_predictions['type'] = typee

    # Объединение временного DataFrame с основным датасетом
    lv_predictions_full = pd.concat([lv_predictions_full, lv_predictions],
                                    ignore_index=True)
    del lv_predictions, preds, test_candidates

    # lv_predictions.to_parquet(f'lv_predictions_{typee}.parquet')
    # shutil.copy2(f'lv_predictions_{typee}.parquet', f'{main_path}/lv/{ver_folder}/lv_predictions_{typee}.parquet' )
# Out:
# type:   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:02,  1.69it/s]
#  40%|████      | 2/5 [00:01<00:02,  1.12it/s]
#  60%|██████    | 3/5 [00:03<00:02,  1.09s/it]
#  80%|████████  | 4/5 [00:04<00:01,  1.31s/it]
# 100%|██████████| 5/5 [00:06<00:00,  1.30s/it]
# type:  33%|███▎      | 1/3 [01:21<02:43, 81.83s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:02,  1.75it/s]
#  40%|████      | 2/5 [00:01<00:02,  1.15it/s]
#  60%|██████    | 3/5 [00:02<00:02,  1.06s/it]
#  80%|████████  | 4/5 [00:04<00:01,  1.28s/it]
# 100%|██████████| 5/5 [00:06<00:00,  1.27s/it]
# type:  67%|██████▋   | 2/3 [02:28<01:12, 72.71s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:02,  1.76it/s]
#  40%|████      | 2/5 [00:01<00:02,  1.15it/s]
#  60%|██████    | 3/5 [00:02<00:02,  1.07s/it]
#  80%|████████  | 4/5 [00:04<00:01,  1.29s/it]
# 100%|██████████| 5/5 [00:06<00:00,  1.29s/it]
# type: 100%|██████████| 3/3 [03:32<00:00, 70.85s/it]

# %%
id2type_name = 'id2type.pkl'
# version = 'ver_6.1'

# %%
valid = pd.read_parquet(f'{main_path}/s/test_labels_loc.parquet')

with open(f'{main_path}/pkl/{id2type_name}', 'rb') as file:
    id2type = pickle.load(file)

print('Model score :', metric_eval(lv_predictions_full, valid, id2type))
# Out:
# Model score : (0.5271976703740328, type
# carts     0.368052
# clicks    0.398249
# orders    0.628262
# dtype: float64)

# %%
best_score_base = {
    'xgb': 0.5220552152693079,
    'lgbm': 0.5248555778378172,
    'catb': 0.5271976703740328
}

# %% [markdown]
# ## Тренировка с кросс-валидацией

# %%
for typee in tqdm(['clicks', 'carts', 'orders'], desc='type'):

    path = f'{main_path}/tr/ver_6/tr_candidates_{typee}/*'
    tr_candidates = read_parquets(path)
    print('reading_done')

    tr_candidates.session = tr_candidates.session.astype(np.int32)
    tr_candidates.aid = tr_candidates.aid.astype(np.int32)

    class_ratio = tr_candidates['target'].value_counts()[1] / \
                  tr_candidates['target'].value_counts()[0]

    # Указываем желаемое соотношение классов
    under_sampler = RandomUnderSampler(sampling_strategy=class_ratio *
                                       downsamp_k)

    # downsamling для лучшего баланса классов
    FEATURES = tr_candidates.columns[:-1]
    X = tr_candidates.loc[:, FEATURES]
    y = tr_candidates.loc[:, 'target']
    X_train, y_train = under_sampler.fit_resample(X, y)
    tr_candidates = pd.merge(X_train,
                             y_train,
                             left_index=True,
                             right_index=True)
    tr_candidates = tr_candidates.sort_values('session')
    tr_candidates = tr_candidates.reset_index(drop=True)

    del X, y
    print('sampling_done')

    # Обучение модели
    skf = GroupKFold(n_splits=5)
    FEATURES = tr_candidates.columns[:-1]

    scores = []

    for fold, (train_idx, valid_idx) in enumerate(
            skf.split(tr_candidates,
                      tr_candidates['target'],
                      groups=tr_candidates['session'])):

        X_train = tr_candidates.loc[train_idx, FEATURES]
        y_train = tr_candidates.loc[train_idx, 'target']
        X_valid = tr_candidates.loc[valid_idx, FEATURES]
        y_valid = tr_candidates.loc[valid_idx, 'target']

        group_id_tr = X_train.iloc[:, 0]
        group_id_v = X_valid.iloc[:, 0]

        X_train = X_train.iloc[:, 2:]
        X_valid = X_valid.iloc[:, 2:]

        catboost_train = Pool(data=X_train,
                              label=y_train,
                              group_id=group_id_tr)
        catboost_valid = Pool(data=X_valid, label=y_valid, group_id=group_id_v)

        ranker = CatBoostRanker(loss_function='PairLogit',
                                task_type='GPU',
                                random_state=42)
        ranker.fit(catboost_train,
                   eval_set=catboost_valid,
                   early_stopping_rounds=50,
                   verbose=False)

        # Рассчитать метрику pairlogit
        pairlogit = ranker.best_score_['validation']['PairLogit']
        scores.append(pairlogit)

        folder_path = f'model/baseline/{ver_folder}_kfolds'
        os.makedirs(folder_path, exist_ok=True)
        ranker.save_model(
            f'model/baseline/{ver_folder}_kfolds/catb_base_{fold}_{typee}')
    # Усреднить pairlogit по всем фолдам
    pairlogit_mean = np.mean(scores)
    print(f'pairlogit_mean_{typee}:', pairlogit_mean)

    # Сохранение модели на диск
    # folder_path = f'{main_path}/models/{ver_folder}/'
    # os.makedirs(folder_path, exist_ok=True)

    # file_list = glob.glob(f'/content/model/*{typee}.xgb')
    # [shutil.copy(file, f'{main_path}/models/{ver_folder}/') for file in file_list]
# Out:
# type:   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:09,  2.29s/it]
#  40%|████      | 2/5 [00:05<00:08,  2.98s/it]
#  60%|██████    | 3/5 [00:09<00:07,  3.53s/it]
#  80%|████████  | 4/5 [00:14<00:03,  3.97s/it]
# 100%|██████████| 5/5 [00:20<00:00,  4.00s/it]
# reading_done
# sampling_done
# type:  33%|███▎      | 1/3 [05:14<10:28, 314.04s/it]
# pairlogit_mean_clicks: 0.39510939463998984
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:04<00:18,  4.63s/it]
#  40%|████      | 2/5 [00:10<00:16,  5.61s/it]
#  60%|██████    | 3/5 [00:17<00:12,  6.24s/it]
#  80%|████████  | 4/5 [00:25<00:06,  6.91s/it]
# 100%|██████████| 5/5 [00:34<00:00,  6.94s/it]
# reading_done
# sampling_done
# type:  67%|██████▋   | 2/3 [09:37<04:44, 284.56s/it]
# pairlogit_mean_carts: 0.3072526368101608
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:05<00:20,  5.13s/it]
#  40%|████      | 2/5 [00:12<00:18,  6.21s/it]
#  60%|██████    | 3/5 [00:18<00:12,  6.15s/it]
#  80%|████████  | 4/5 [00:25<00:06,  6.62s/it]
# 100%|██████████| 5/5 [00:33<00:00,  6.79s/it]
# reading_done
# sampling_done
# type: 100%|██████████| 3/3 [13:55<00:00, 278.63s/it]
# pairlogit_mean_orders: 0.19181008929776722

# %% [markdown]
# ## Pairlogit's каждого типа Cross-val

# %% [markdown]
#  - pairlogit_mean_clicks: 0.395109
#  - pairlogit_mean_carts: 0.307252
#  - pairlogit_mean_orders: 0.191810

# %% [markdown]
# ## Предсказание + оценка (кросс-валидация

# %%
lv_predictions_full = pd.DataFrame()

for typee in tqdm(['clicks', 'carts', 'orders'], desc='type'):

    if os.path.exists(f'/content/test_candidates_{typee}') == False:
        # импорт кандидатов выбранного типа
        shutil.copytree(f'{main_path}/lv/ver_6/test_candidates_{typee}/',
                        f'/content/test_candidates_{typee}/')

    path = f'test_candidates_{typee}/*'
    test_candidates = read_parquets(path)
    test_candidates = test_candidates.sort_values('session')
    test_candidates = test_candidates.reset_index(drop=True)

    FEATURES = test_candidates.columns[2:]
    dtest = Pool(data=test_candidates[FEATURES])
    preds = np.zeros(len(test_candidates))
    for fold in tqdm(range(5)):
        model = CatBoostRanker(random_state=42)
        model.load_model(
            f'model/baseline/{ver_folder}_kfolds/catb_base_{fold}_{typee}')
        fold_preds = model.predict(dtest)
        preds += fold_preds / 5

    lv_predictions = test_candidates[['session', 'aid']].copy()
    lv_predictions['pred'] = preds
    lv_predictions = lv_predictions.sort_values(
        ['session', 'pred'], ascending=[True, False]).reset_index(drop=True)
    lv_predictions['n'] = lv_predictions.groupby(
        'session').aid.cumcount().astype('int8')
    lv_predictions = lv_predictions.loc[lv_predictions.n < 20]
    lv_predictions = lv_predictions.groupby('session').aid.apply(list)
    lv_predictions = lv_predictions.to_frame().reset_index()
    lv_predictions.rename(columns={'aid': 'labels'}, inplace=True)
    lv_predictions['type'] = typee

    # Объединение временного DataFrame с основным датасетом
    lv_predictions_full = pd.concat([lv_predictions_full, lv_predictions],
                                    ignore_index=True)
    del lv_predictions, preds, test_candidates

    # lv_predictions.to_parquet(f'lv_predictions_{typee}.parquet')
    # shutil.copy2(f'lv_predictions_{typee}.parquet', f'{main_path}/lv/{ver_folder}/lv_predictions_{typee}.parquet' )
# Out:
# type:   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:02,  1.53it/s]
#  40%|████      | 2/5 [00:01<00:03,  1.01s/it]
#  60%|██████    | 3/5 [00:03<00:02,  1.20s/it]
#  80%|████████  | 4/5 [00:05<00:01,  1.44s/it]
# 100%|██████████| 5/5 [00:07<00:00,  1.43s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:11<00:44, 11.07s/it]
#  40%|████      | 2/5 [00:21<00:32, 10.89s/it]
#  60%|██████    | 3/5 [00:32<00:21, 10.63s/it]
#  80%|████████  | 4/5 [00:42<00:10, 10.58s/it]
# 100%|██████████| 5/5 [00:53<00:00, 10.70s/it]
# type:  33%|███▎      | 1/3 [01:55<03:51, 115.91s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:02,  1.41it/s]
#  40%|████      | 2/5 [00:01<00:02,  1.04it/s]
#  60%|██████    | 3/5 [00:03<00:02,  1.21s/it]
#  80%|████████  | 4/5 [00:05<00:01,  1.45s/it]
# 100%|██████████| 5/5 [00:07<00:00,  1.44s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:10<00:41, 10.37s/it]
#  40%|████      | 2/5 [00:21<00:31, 10.63s/it]
#  60%|██████    | 3/5 [00:31<00:20, 10.48s/it]
#  80%|████████  | 4/5 [00:41<00:10, 10.32s/it]
# 100%|██████████| 5/5 [00:52<00:00, 10.42s/it]
# type:  67%|██████▋   | 2/3 [03:46<01:52, 112.84s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:02,  1.44it/s]
#  40%|████      | 2/5 [00:01<00:02,  1.00it/s]
#  60%|██████    | 3/5 [00:03<00:02,  1.22s/it]
#  80%|████████  | 4/5 [00:05<00:01,  1.45s/it]
# 100%|██████████| 5/5 [00:07<00:00,  1.43s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:10<00:41, 10.34s/it]
#  40%|████      | 2/5 [00:20<00:31, 10.49s/it]
#  60%|██████    | 3/5 [00:32<00:21, 10.90s/it]
#  80%|████████  | 4/5 [00:42<00:10, 10.63s/it]
# 100%|██████████| 5/5 [00:52<00:00, 10.52s/it]
# type: 100%|██████████| 3/3 [05:37<00:00, 112.50s/it]

# %%
id2type_name = 'id2type.pkl'
# version = 'ver_6.1'

# %%
valid = pd.read_parquet(f'{main_path}/s/test_labels_loc.parquet')

with open(f'{main_path}/pkl/{id2type_name}', 'rb') as file:
    id2type = pickle.load(file)

print('Model score :', metric_eval(lv_predictions_full, valid, id2type))
# Out:
# Model score : (0.5271169524492465, type
# carts     0.368120
# clicks    0.397638
# orders    0.628195
# dtype: float64)

# %% [markdown]
# # Вывод

# %%
best_score_base = {
    'xgb': 0.5220552152693079,
    'lgbm': 0.5248555778378172,
    'catb': 0.5271169524492465
}

# %% [markdown]
# **Лучшую метрику показал CatBoost Ranker**
# Продолжу его тюнинг
